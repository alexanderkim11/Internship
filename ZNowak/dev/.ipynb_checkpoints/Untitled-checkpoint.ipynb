# %%
import collections
from typing import Dict, List, Tuple


def text2bow(words: List[str], dictionary: Dict[str, int]) -> List[Tuple[int, int]]:
    word_frequences = collections.defaultdict(int)
    for word in words:
        if word not in dictionary:
            dictionary[word] = len(dictionary)
        word_frequences[dictionary[word]] += 1
 
    return list(word_frequences.items())

# %%
with open("C:\\Users\\znowak\Anaconda3\\Lib\\site-packages\\pattern\\text\\en\\en-lexicon.txt", "r", encoding = "utf8") as f:
    print(f.readlines()[0])
# Out:
# ;;;

# %%
# %load_ext Cython

# %%
# %%cython -a
#
# def fibonacci(n):
#     if n < 0:
#         print("1st fibonacci number = 0")
#     elif n == 1:
#         return 0
#     elif n == 2:
#         return 1
#     else:
#         return fibonacci(n-1) + fibonacci(n-2)
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.21 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_db6142ce43cb2a828a90cd3912b361b6.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-colo

# %%
# %%cython -a
# with open("C:\\Users\\znowak\Anaconda3\\Lib\\site-packages\\pattern\\text\\en\\en-lexicon.txt", "r", encoding = "utf8") as f:
#     print(f.readlines()[0])
# Out:
# ;;;
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.21 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_2743c020aff3a79a2705a1bcbd8fe42c.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-colo

# %%
# %%cython -f
# # distutils: extra_compile_args = -fopenmp
# # distutils: extra_link_args = -fopenmp
# # cython: language_level=3
# # cython: embedsignature=True
# # cython: profile=True
# # cython: boundscheck=False
# # coding: utf8
#
# from libc.stdlib cimport malloc, realloc, free
# from libc.stdio cimport fopen, fclose, FILE, EOF, fseek, SEEK_END, SEEK_SET
# from libc.stdio cimport ftell, fgetc, fgets, getc, gets, feof, fread, getline
# from libc.string cimport strlen, memcpy, strcpy, strtok, strchr, strncpy
# from cython.parallel import prange, parallel, threadid
#
# # - C structure that is set to readonly
# cdef readonly struct FileContents:
#     char *contents
#
# cdef class CyReadFile:
#     """Read in the contents of a file."""
#     cdef:
#         FileContents *File
#         FILE *fp
#         char *filename
#         char *delimiter
#         long file_size
#         bint is_open
#         bint EO_STR
#
#     def __init__(self, char *delimiter, char *filename):
#         self.File = <FileContents*>malloc(sizeof(CyReadFile))
#         self.delimiter = delimiter
#         self.filename = filename
#         self.File.contents = NULL
#         self.is_open = 0
#         self.EO_STR = 0
#         self.file_size = 0
#         self.fp = NULL
#
#     def open_file(self):
#         """Open the file for reading."""
#         self.fp = fopen(self.filename, "r")
#         if self.fp == NULL:
#             raise FileNotFoundError(2, "No such file or directory: '%s'" % self.filename)
#         else:
#             # file is now open
#             self.is_open = 1
#
#     def read_in_file(self):
#         """Read in the entire file."""
#         if self.is_open == 1:
#             # get the length of the file
#             fseek(self.fp, 0, SEEK_END)
#             self.file_size = ftell(self.fp)
#             fseek(self.fp, 0, SEEK_SET)
#             # allocate memory for reading in the file
#             self.File.contents = <char*>malloc(self.file_size*sizeof(char))
#             # read entire file into the struct
#             fread(self.File.contents, 1, self.file_size, self.fp)
#             # close the file once it's read into the char array
#             fclose(self.fp)
#             # set is_open to 0
#             self.is_open = 0
#
#     def read_file_in_parallel(self):
#         """Bypass the gil and read in the file."""
#         if self.is_open == 1:
#             with nogil:
#                 # get the length of the file
#                 fseek(self.fp, 0, SEEK_END)
#                 self.file_size = ftell(self.fp)
#                 fseek(self.fp, 0, SEEK_SET)
#                 # allocate memory for reading in the file
#                 self.File.contents = <char*>malloc(self.file_size*sizeof(char))
#                 # read entire file into the struct
#                 fread(self.File.contents, 1, self.file_size, self.fp)
#                 # close the file once it's read into the char array
#                 fclose(self.fp)
#                 # set is_open to 0
#                 self.is_open = 0
#
#     def __dealloc__(self):
#         """Deallocate memory"""
#         free(self.File.contents)
#         free(self.File)
#         free(self.fp)
#         free(self.filename)
#         free(self.delimiter)
#
#
# # - To use the cython class, we must create a python subclass that inherits from it.
# # - I will set the cython variables concretely in the Python subclass
#
# # test data
# emlFile = "en-lexicon.txt"
#
# class PyReadFile(CyReadFile):
#     """A python wrapper around a cython class."""
#     def __init__(self):
#         super().__init__(b',', emlFile)
#
#
# def py_read_file(filename):
#     with open(filename, "r", encoding="utf-8") as f:
#         return f.read()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\znowak\Documents\Projects\testNLP\dev

# %%
# %%cython
# from __future__ import print_function
# from libc.stdio cimport FILE, fopen, fseek, fclose, SEEK_END, SEEK_SET, ftell, fread
# from libc.stdlib cimport malloc, free
# from cpython.exc cimport PyErr_SetFromErrnoWithFilenameObject
#
#
# def open_file_cy():
#     cdef FILE* p
#     p = fopen("en-lexicon.txt", "r")
#     if p is NULL:
#         PyErr_SetFromErrnoWithFilenameObject(OSError, "spam.txt")
#         return None
#     else:
#         # get the length of the file
#         fseek(p, 0, SEEK_END)
#         file_size = ftell(p)
#         fseek(p, 0, SEEK_SET)
#         # allocate memory for reading in the file
#         contents = <char*>malloc(file_size*sizeof(char))
#         # read entire file into the struct
#         fread(contents, 1, file_size, p)
#         # close the file once it's read into the char array
#         fclose(p)
#         return contents
#
# def open_file_py():
#     with open("en-lexicon.txt", "r", encoding="utf-8") as f:
#         return f.read()

# %%
# %timeit open_file_cy()
# %timeit open_file_py()
# Out:
# 5.94 ms ± 496 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.4 ms ± 4.37 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
RP\n\'N NNP\n\'Nightline NNP\n\'No UH\n\'OK UH\n\'Oh UH\n\'Okay UH\n\'Onward RB\n\'Ounce NNP\n\'P JJ\n\'People NNS\n\'Poltergeist NN\n\'Preventive JJ\n\'R NNP\n\'RED JJ\n\'Recovering VBG\n\'S VBZ\n\'Son NN\n\'Sorry JJ\n\'Struggling VBG\n\'Sweets NNP\n\'T- PRP\n\'Tahiti NNP\n\'That\'s VBZ\n\'The NNP\n\'This VBZ\n\'Three\'s NNP\n\'Tide NNP\n\'To NNP\n\'Today NNP\n\'Unsolved NNP\n\'Wadoo UH\n\'War NNP\n\'Watch VB\n\'We PRP\n\'We\'ve PRP\n\'Well RB\n\'What WP\n\'Which NN\n\'Who NN\n\'Why WRB\n\'Will MD\n\'X NN\n\'Yeah UH\n\'Yes UH\n\'You NN\n\'Yuk UH\n\'`` ``\n\'bout IN\n\'ceptin VBG\n\'d MD\n\'d. NN\n\'ello UH\n\'em PRP\n\'emselves PRP\n\'fess VB\n\'fore IN\n\'im PRP\n\'ll MD\n\'low VB\n\'m VBP\n\'mon UH\n\'most IN\n\'n IN\n\'nother DT\n\'nough JJ\n\'nuff RB\n\'pache NN\n\'re VBP\n\'re... :\n\'round RB\n\'s POS\n\'s. POS\n\'scuse VB\n\'stead IN\n\'t- PRP\n\'thirties NNS\n\'till IN\n\'ve VBP\n\'way RB\n\'we\'d MD\n( (\n(!) SYM\n(3/26 1991)\n(9/9 1991)\n(: SYM\n(@ SYM\n) )\n). SYM\n): SYM\n* SYM\n+ SYM\n, ,\n,\'cept IN\n,\'t- PRP\n,. SYM\n,.. NN\n,... :\n- :\n-$ $\n-- :\n--$ $\n--\'cause JJ\n--271,124 CD\n--33 CD\n--4.8 CD\n--Boca NNP\n--Bordeaux NNP\n--China NNP\n--Dell NNP\n--Dorothy NNP\n--George NNP\n--Hitachi NNP\n--Mrs NNP\n--Of IN\n--Thailand NNP\n--Tokyo NNP\n--William NNP\n--a DT\n--about IN\n--agreed NN\n--all DT\n--and CC\n--are VBP\n--at IN\n--awarding VBG\n--changed VBD\n--combined VBN\n--complicated IN\n--consented VBD\n--considered VBN\n--despite IN\n--didn\'t VBD|RB\n--dividends NNS\n--especially RB\n--even JJ\n--fawning VBG\n--fell  ...

# %%
# %%cython
# from __future__ import print_function
# from libc.stdio cimport FILE, fopen, fseek, fclose, SEEK_END, SEEK_SET, ftell, fread, getc
# from libc.stdlib cimport malloc, free
# from cpython.exc cimport PyErr_SetFromErrnoWithFilenameObject
# # Count the number of NN
# def count_lines_cy(char* string):
#     cdef int count = 0
#     for c in string:
#         if (c == b'\n'):
#             count = count + 1;
#     return count
#
# def count_lines_py(string):
#     return string.count(b'\n')

# %%
string = open_file_cy()
# %timeit count_lines_cy(string)
# %timeit count_lines_py(string)

#94258
# Out:
# 4.12 ms ± 583 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.93 ms ± 32.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit string.split(b"\n")
string_list = string.split(b'\n')
# Out:
# 11.2 ms ± 494 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%cython
# from __future__ import print_function
# cimport cython
# from libc.stdio cimport FILE, fopen, fseek, fclose, SEEK_END, SEEK_SET, ftell, fread, fgets, rewind
# from libc.stdlib cimport malloc, free
# from cpython.exc cimport PyErr_SetFromErrnoWithFilenameObject
# from libc.string cimport strcpy, strlen
#
#
# def read_lines():
#     cdef:
#         char** array        # Array of lines */
#         int    i                   # Loop counter */
#         char   line[100]           # Buffer to read each line */
#         int    line_count          # Total number of lines */
#         int    line_length         # Length of a single line */
#         FILE* txt   #file of interest */
#
#     # Open the file
#     txt = fopen("en-lexicon.txt", "r")
#     if txt is NULL:
#         PyErr_SetFromErrnoWithFilenameObject(OSError, "en-lexicon.txt")
#         return
#
#     # Clear output parameter. */
#     array = NULL
#     arr = []
#
#     # Get the count of lines in the file */
#     line_count = 0;
#     while (fgets(line, sizeof(line), txt) != NULL):
#         line_count+=1;
#
#     # Move to the beginning of file. */
#     rewind(txt);
#
#     # Allocate an array of pointers to strings
#      # (one item per line). */
#     array = <char**>malloc(line_count * sizeof(char*));
#     if (array == NULL):
#         return;
#
#
#     # Read each line from file and deep-copy in the array. */
#     for i in range(line_count):
#         # Read the current line. */
#         fgets(line, sizeof(line), txt);
#
#         # Remove the ending '\n' from the read line. */
#         line_length = strlen(line);
#         line[line_length - 1] = b'\0';
#         line_length-=1; # update line length */
#
#         # Allocate space to store a copy of the line. +1 for NUL terminator */
#         array[i] = <char*>malloc(line_length + 1);
#
#         # Copy the line into the newly allocated space. */
#         strcpy(array[i], line);
#         arr.append(<object>line)
#     return arr

# %%
# %%cython
# from __future__ import print_function
# cimport cython
# from libc.stdio cimport FILE, fopen, fseek, fclose, SEEK_END, SEEK_SET, ftell, fread, fgets, rewind
# from libc.stdlib cimport malloc, free
# from cpython.exc cimport PyErr_SetFromErrnoWithFilenameObject
# from libc.string cimport strcpy, strlen
# import re
#
#
# def read_lines():
#     cdef:
#         int    i                   # Loop counter */
#         char   line[100]           # Buffer to read each line */
#         int    line_count          # Total number of lines */
#         int    line_length         # Length of a single line */
#         FILE* txt                  # File of interest */
#
#     # Open the file
#     txt = fopen("en-lexicon.txt", "r")
#
#     # Clear output parameter. */
#     arr = []
#
#     # Get the count of lines in the file */
#     line_count = 94258
#
#
#     # Read each line from file and deep-copy in the array. */
#     for i in range(line_count):
#         # Read the current line. */
#         fgets(line, sizeof(line), txt);
#         length = strlen(line)
#         if line[length-3] == b'N':
#             if line[length-4] == b' ':
#                 temp = line[:length-4]
#                 arr.append(temp)
#             else:
#                 temp = line[:length-5]
#                 arr.append(temp)
#
#     fclose(txt)
#     return arr
# def read_lines_py():
#     cdef FILE* txt                  # File of interest */
#
#     # Open the file
#     p = fopen("en-lexicon.txt", "r")
#     # get the length of the file
#     fseek(p, 0, SEEK_END)
#     file_size = ftell(p)
#     fseek(p, 0, SEEK_SET)
#     # allocate memory for reading in the file
#     contents = <char*>malloc(file_size*sizeof(char))
#     # read entire file into the struct
#     fread(contents, 1, file_size, p)
#     # close the file once it's read into the char array
#     fclose(p)
#     temp = (<bytes>contents).decode('utf-8')
#     # temp = <bytes>contents
#     # return temp.split(b"\n") #15 ms
#     return re.findall(r'\w+(?= NN)', temp)

# %%
# %timeit read_lines()
# %timeit read_lines_py()
# Out:
# 23.9 ms ± 999 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 191 ms ± 1.74 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
read_lines()
# Out:
# [b'#GLEE',
#  b'#Glee',
#  b'#fail',
#  b'#fb',
#  b'#glee',
#  b'#shoutout',
#  b'#win',
#  b'%',
#  b'%CHG',
#  b'&0C.',
#  b"''.",
#  b"'40s",
#  b"'50s",
#  b"'60s",
#  b"'70s",
#  b"'80s",
#  b"'89s",
#  b"'90s",
#  b"'A",
#  b"'BS",
#  b"'Channel",
#  b"'Chief",
#  b"'D",
#  b"'Dividend",
#  b"'Do",
#  b"'Em",
#  b"'God",
#  b"'Goodison",
#  b"'Guesstimates",
#  b"'Hagura",
#  b"'Happy",
#  b"'Here's",
#  b"'I've",
#  b"'Il",
#  b"'K",
#  b"'Lady",
#  b"'MTV",
#  b"'Ma",
#  b"'N",
#  b"'Nightline",
#  b"'Ounce",
#  b"'People",
#  b"'Poltergeist",
#  b"'R",
#  b"'Son",
#  b"'Sweets",
#  b"'Tahiti",
#  b"'The",
#  b"'Three's",
#  b"'Tide",
#  b"'To",
#  b"'Today",
#  b"'Unsolved",
#  b"'War",
#  b"'Which",
#  b"'Who",
#  b"'X",
#  b"'You",
#  b"'d.",
#  b"'pache",
#  b"'thirties",
#  b',..',
#  b'--Boca',
#  b'--Bordeaux',
#  b'--China',
#  b'--Dell',
#  b'--Dorothy',
#  b'--George',
#  b'--Hitachi',
#  b'--Mrs',
#  b'--Thailand',
#  b'--Tokyo',
#  b'--William',
#  b'--agreed',
#  b'--dividends',
#  b'--in',
#  b'--meal',
#  b'--players',
#  b'--products',
#  b'--subjects',
#  b'--wines',
#  b'-16-degrees CD',
#  b'-20-degrees CD',
#  b'-20-degrees-C CD|N',
#  b'-78-degrees C',
#  b'-Samuel',
#  b'-Yr.',
#  b'-aminometha',
#  b'-axis',
#  b'-c',
#  b'-ism',
#  b".'crack",
#  b'2day',
#  b'======================================ll',
#  b'@BarackObama',
#  b'@DailySexTips',
#  b'@NICKIMINAJ',
#  b'@NickiMinaj',
#  b'@justinbieber',
#  b'@kylieminogue',
#  b'@youtube',
#  b'A&E',
#  b'A&M',
#  b'A&P',
#  b'A&W',
#  b'A*/NNP&S',
#  b'A,B,C,D',
#  b'A-12',
#  b'A-2',
#  b'A-300-600',
#  b'A-310-300',
#  b'A-320',
#  b'A-320-200',
#  b'A-320s',
#  b'A-321',
#  b'A-330',
#  b'A-330s',
#  b'A-340s',
#  b'A-6',
#  b'A-B',
#  b'A-D',
#  b'A-Team',
#  b'A-Z',
#  b'A-bombs',
#  b'A-men',
#  b'A.',
#  b'A.A.',
#  b'A.A.U.',
#  b'A.B.',
#  b'A.C.',
#  b'A.D',
#  b'A.D.',
#  b'A.D.L.',
#  b'A.E.',
#  b'A.F.',
#  b'A.G.',
#  b'A.H.',
#  b'A.I.D.',
#  b'A.I.R.',
#  b'A.J.',
#  b'A.J.C.',
#  b'A.K.C.',
#  b'A.L.',
#  b'A.L.A.M.',
#  b'A.L/NNP.S/NNP.A.C.',
#  b'A.M.',
#  b'A.M.A',
#  b'A.M.A.',
#  b'A.M.E.',
#  b'A.N.',
#  b'A.O.',
#  b'A.P.',
#  b'A.R.',
#  b'A.R.A.',
#  b'A.S.',
#  b'A.T.B.',
#  b'A.V.',
#  b'A.W.',
#  b'A12',
#  b'A135',
#  b'A300-600R',
#  b'A310-300s',
#  b'A320',
#  b'A321s',
#  b'A330',
#  b'A330-300s',
#  b'A340',
#  b'A40-AjK',
#  b'A5',
#  b'AAA',
#  b'AARP',
#  b'AAb',
#  b'AB',
#  b'ABA',
#  b'ABB',
#  b'ABBIE',
#  b'ABC',
#  b'ABC-TV',
#  b'ABCs',
#  b'ABG-Semca',
#  b'ABIOMED',
#  b'ABM',
#  b'ABM.',
#  b'ABO',
#  b'ABORTION',
#  b'ABS',
#  b'ABUSE',
#  b'AC&R',
#  b'AC&R\\/CCL',
#  b'AC-130U',
#  b'ACCEPTANCES',
#  b'ACCO',
#  b'ACCOUNT',
#  b'ACCOUNTANTS',
#  b'ACCOUNTING',
#  b'ACCOUNTS',
#  b'ACLU',
#  b'ACQUISITION',
#  b'ACQUISITIONS',
#  b'ACRES',
#  b'ACS',
#  b'ACT',
#  b'ACTH',
#  b'AD',
#  b'ADB',
#  b'ADC',
#  b'ADIA',
#  b'ADMAN',
#  b"ADMINISTRATION'S",
#  b'ADN',
#  b'ADR',
#  b'ADRs',
#  b'ADT',
#  b'ADV',
#  b'ADVANCED',
#  b'ADVANCEMENT',
#  b'ADVANCES',
#  b'ADVERTISERS',
#  b'ADVERTISING',
#  b'AD\\',
#  b'AEC',
#  b'AEG',
#  b'AEI',
#  b'AEP',
#  b'AES',
#  b'AEW',
#  b'AF',
#  b'AFDC',
#  b'AFL-CIO',
#  b'AFP',
#  b'AFRICA',
#  b"AFRICA'S",
#  b'AFTERMATH',
#  b'AFTERSHOCKS',
#  b'AG',
#  b'AGA',
#  b'AGE',
#  b'AGENCIES',
#  b'AGENCY',
#  b'AGF',
#  b'AGI',
#  b'AGIP',
#  b'AGS',
#  b'AH-64',
#  b'AHSC',
#  b'AIA',
#  b'AIB',
#  b'AIB.PR',
#  b'AIChE',
#  b'AID',
#  b'AIDS',
#  b'AIDS-treatment',
#  b'AIEE',
#  b'AIG',
#  b'AIM',
#  b'AIMO',
#  b'AIR',
#  b"AIR'S",
#  b'AIRCOA',
#  b'AIW',
#  b'AK-47',
#  b'AL',
#  b'ALAMCO',
#  b'ALBERTA',
#  b'ALCEE',
#  b'ALCOHOL',
#  b'ALERT',
#  b'ALII',
#  b'ALLIANCE',
#  b'ALLWASTE',
#  b'ALLY',
#  b'ALPA',
#  b'ALQ-135',
#  b'ALQ-178',
#  b'ALT',
#  b'ALU',
#  b'ALUMINUM',
#  b'AM',
#  b'AMA',
#  b'AMBASSADOR',
#  b'AMC',
#  b'AMCA',
#  b'AMDAHL',
#  b"AMERICA'S",
#  b'AMERICAN',
#  b'AMERICANS',
#  b'AMES',
#  b'AMEX',
#  b'AMF',
#  b'AMI',
#  b'AMNESTY',
#  b'AMP',
#  b'AMR',
#  b'AMR-Delta',
#  b'AMRO',
#  b'AMT',
#  b'AMVISC',
#  b'AMs',
#  b'ANACOMP',
#  b'ANB',
#  b'ANC',
#  b'ANCHORAGE',
#  b'ANDERSEN',
#  b'ANF',
#  b'ANF-Industrie',
#  b'ANGELES',
#  b'ANIMAL-RIGHTS',
#  b'ANN',
#  b'ANNUITIES',
#  b'ANNUITY',
#  b'ANP',
#  b'ANR',
#  b'ANSA',
#  b'ANTHEM',
#  b'ANZ',
#  b'AON',
#  b'AP',
#  b'AP-Dow',
#  b'AP600',
#  b'APARTHEID',
#  b'API',
#  b'APM',
#  b'APMS',
#  b'APPB',
#  b'APPELLATE',
#  b'APPLE',
#  b'APPLIED',
#  b'APS',
#  b'APT',
#  b'APV',
#  b'ARA',
#  b'ARAL-88',
#  b'ARBITRAGE',
#  b'ARCO',
#  b'AREA',
#  b'ARF',
#  b'ARM',
#  b'ARMs',
#  b'ARNOLD',
#  b'ARTICLE',
#  b'ARTY',
#  b'ART\\/artifact',
#  b'AS',
#  b'ASA',
#  b'ASARCO',
#  b'ASC',
#  b'ASCAP',
#  b'ASDA',
#  b'ASDIC',
#  b'ASEA',
#  b'ASEAN',
#  b'ASHTON-TATE',
#  b'ASK',
#  b'ASKO',
#  b'ASLACTON',
#  b'ASME',
#  b'ASP',
#  b'ASPR',
#  b'ASSETS',
#  b'ASSOCIATES',
#  b'ASSOCIATION',
#  b'ASSOCIATION-COLLEGE',
#  b'AST',
#  b'ASW',
#  b'AS\\',
#  b'AT&T',
#  b'AT*',
#  b'AT*/NNP&T',
#  b'ATARI',
#  b'ATHLONE',
#  b'ATI',
#  b'ATLANTIC',
#  b'ATM',
#  b'ATMs',
#  b'ATP',
#  b'ATS\\',
#  b'ATTACK',
#  b'ATTORNEY',
#  b'AUDITS',
#  b'AUS',
#  b'AUSTIN',
#  b'AUTO',
#  b'AVC',
#  b'AVON',
#  b'AVX',
#  b'AWA',
#  b'AWE',
#  b'AWOC',
#  b'AYER',
#  b'AZT',
#  b'AZTR',
#  b'A\\/S',
#  b'Aalseth',
#  b'Aaron',
#  b'Aaronson',
#  b'Aarvik',
#  b'Ab1,040',
#  b'Ababa',
#  b'Abalkin',
#  b'Abatuno',
#  b'Abba',
#  b'Abbas',
#  b'Abbe',
#  b'Abbe-Direct',
#  b'Abbe-Scotch',
#  b'Abbenhaus',
#  b'Abbett',
#  b'Abbey',
#  b'Abbie',
#  b'Abbot',
#  b'Abbott',
#  b'Abboud',
#  b'Abby',
#  b'Abd-al-Aziz',
#  b'Abdallah',
#  b'Abderahmane',
#  b'Abdul',
#  b'Abdul-Raheem',
#  b'Abdullah',
#  b'Abe',
#  b'Abel',
#  b'Abell',
#  b'Abello',
#  b'Abelson',
#  b'Abend',
#  b'Abercrombie',
#  b'Aberdeen',
#  b'Abernathy',
#  b'Abex',
#  b'Abide',
#  b'Abie',
#  b'Abigail',
#  b'Abilene',
#  b'Abingdon',
#  b'Abiomed',
#  b'Abitibi-Price',
#  b'Ablard',
#  b'Able',
#  b'Abner',
#  b'Abney',
#  b'Aboff',
#  b'Abolition',
#  b'Abolitionists',
#  b'Abortion',
#  b'Abortion-rights',
#  b'Abra',
#  b'Abraham',
#  b'Abrahams',
#  b'Abrahamson',
#  b'Abramowitz',
#  b'Abrams',
#  b'Abramson',
#  b'Abreaction',
#  b'Abreast',
#  b'Absenteeism',
#  b'Absolution',
#  b'Abstract',
#  b'Abstraction',
#  b'Abstractionists',
#  b'Abstractions',
#  b'Abstracts',
#  b'Abt',
#  b'Abu',
#  b'Abuse',
#  b'Abyss',
#  b'Aca',
#  b'Academic',
#  b'Academicianship',
#  b'Academics',
#  b'Academy',
#  b'Acadia',
#  b'Acala',
#  b'Acapulco',
#  b'Acarbose',
#  b'Accacia',
#  b'Accademia',
#  b'Accardo',
#  b'Acceptance',
#  b'Access',
#  b'Accessories',
#  b'Accident',
#  b'Acclaim',
#  b'Accomplishments',
#  b'Accor',
#  b'Accord',
#  b'Account',
#  b'Accountemps',
#  b'Accounting',
#  b'Accounting-profession',
#  b'Accounts',
#  b'Accounts-a',
#  b'Accudyne',
#  b'Accumaster',
#  b'Accumulation',
#  b'Accuracy',
#  b'Accused',
#  b'Accutane',
#  b'Ace',
#  b'Aces',
#  b'Acey',
#  b'Achenbaum',
#  b'Acheson',
#  b'Achievement',
#  b'Achilles',
#  b'Ackerley',
#  b'Ackerly',
#  b'Ackerman',
#  b'Ackermann',
#  b'Ackroyd',
#  b'Acme-Cleveland',
#  b'Acorn',
#  b'Acorns',
#  b'Acourse',
#  b'Acoustic',
#  b'Acquirer',
#  b'Acquirers',
#  b'Acquisition',
#  b'Acquisitions',
#  b'Acreage',
#  b'Acres',
#  b'Acropolis',
#  b'Acrylic',
#  b'Act',
#  b'Acting',
#  b'Acting-President',
#  b'Action',
#  b'Actions',
#  b'Activists',
#  b'Activities',
#  b'Activity',
#  b'Acton',
#  b'Actor-Crooner',
#  b'Actress',
#  b'Acura',
#  b'Acushnet',
#  b'Acustar',
#  b'Acuvue',
#  b'Ad',
#  b'Ad-Unit',
#  b'Ada',
#  b'Adagio',
#  b'Adair',
#  b'Adalbert',
#  b'Adam',
#  b'Adame',
#  b'Adamec',
#  b'Adamo',
#  b'Adams',
#  b'Adamski',
#  b'Adamson',
#  b'Adaptaplex',
#  b'Adaptation',
#  b'Adaptations',
#  b'Adaptec',
#  b'Adcock',
#  b'Addabbo',
#  b'Adde',
#  b'Addict',
#  b'Addicted',
#  b'Addicts',
#  b'Addington',
#  b'Addis',
#  b'Addison',
#  b'Addiss',
#  b'Addition',
#  b'Additive',
#  b'Address',
#  b'Addwest',
#  b'Ade',
#  b'Adelaide',
#  b'Adele',
#  b'Adelia',
#  b'Adella',
#  b'Adelman',
#  b'Adelos',
#  b'Aden',
#  b'Adenauer',
#  b'Adens',
#  b'Adherence',
#  b'Adi',
#  b'Adia',
#  b'Adios',
#  b'Adios-Direct',
#  b'Adios-On',
#  b'Adios-Rena',
#  b'Adios-Trustful',
#  b'Adirondack',
#  b'Adjournment',
#  b'Adjusted',
#  b'Adjusters',
#  b'Adjustment',
#  b'Adlai',
#  b'Adler',
#  b'Adley',
#  b'Adm.',
#  b'Admarketing',
#  b'Admassy',
#  b'Administration',
#  b'Administrative',
#  b'Administrator',
#  b'Admiralty',
#  b'Admirers',
#  b'Admission',
#  b'Admissions',
#  b'Admistration',
#  b'Adnan',
#  b'Ado',
#  b'Adobe',
#  b'Adolescents',
#  b'Adolf',
#  b'Adolph',
#  b'Adolphus',
#  b'Adoniram',
#  b'Adonis',
#  b'Adoption',
#  b'Adoptions',
#  b'Adrar',
#  b'Adrian',
#  b'Adrianople',
#  b'Adriatic',
#  b'Adrien',
#  b'Adrienne',
#  b'Ads',
#  b'Adsi',
#  b'Adult',
#  b'Adultery',
#  b'Adults',
#  b'Advance',
#  b'Advanced',
#  b'Advancement',
#  b'Advancers',
#  b'Advances',
#  b'Advani',
#  b'Advantages',
#  b'Advent',
#  b'Adventists',
#  b'Adventure',
#  b'Adventurers',
#  b'Adventures',
#  b'Advertiser',
#  b'Advertisers',
#  b'Advertising',
#  b'Advertising\\/San',
#  b'Advest',
#  b'Advice',
#  b'Advil',
#  b'Advise',
#  b'Adviser',
#  b'Advisor',
#  b'Advisory',
#  b'Advocate',
#  b'Advocates',
#  b'Aegean',
#  b'Aegis',
#  b'Aegon',
#  b'Aeneid',
#  b'Aer',
#  b'Aeritalia',
#  b'Aermacchi',
#  b'Aero',
#  b'Aero-Space',
#  b'Aerobacter',
#  b'Aeroflot',
#  b'Aerojet',
#  b'Aeromexico',
#  b'Aeronautical',
#  b'Aeronauticas',
#  b'Aeronautics',
#  b'Aeroquip',
#  b'Aerospace',
#  b'Aerospace-Thomson',
#  b'Aerospatiale',
#  b'Aeschbacher',
#  b'Aeschylus',
#  b'Aetna',
#  b'Af-values',
#  b'Af.',
#  b'Afanasyev',
#  b'Afanasyeva',
#  b'Affair',
#  b'Affaire',
#  b'Affaires',
#  b'Affairs',
#  b'Affidavits',
#  b'Affiliated',
#  b'Affiliates',
#  b'Affirmed',
#  b'Affliction',
#  b'Affordable',
#  b'Afghanistan',
#  b'Afghanistan\\/Southwest',
#  b'Afield',
#  b'Afif',
#  b'Aflatoxin',
#  b'Afnasjev',
#  b'Afranio',
#  b'Africa',
#  b'Africaine',
#  b'Africanist',
#  b'Afrika',
#  b'Afrikaaner',
#  b'Afrikanerdom',
#  b'Afrique',
#  b'Afro-Asian',
#  b'Aftereffects',
#  b'Aftershocks',
#  b'AgResource',
#  b'Aga',
#  b'Agamemnon',
#  b'Aganbegyan',
#  b'Agatha',
#  b'Age',
#  b'Agee',
#  b'Agence',
#  b'Agencies',
#  b'Agency',
#  b'Agenda',
#  b'Agent',
#  b'Agents',
#  b'Ageny',
#  b'Agfa',
#  b'Aggie',
#  b'Aggies',
#  b'Aggressive',
#  b'Aghanistan',
#  b'Aghazadeh',
#  b'Agin',
#  b'Aging',
#  b'Agins',
#  b'Agip',
#  b'Agitato',
#  b'Agius',
#  b'Agnelli',
#  b'Agnes',
#  b'Agnese',
#  b'Agnew',
#  b'Agnos',
#  b'Agoeng',
#  b'Agoglia',
#  b'Agonale',
#  b'Agone',
#  b'Agoura',
#  b'Agouron',
#  b'Agreeable',
#  b'Agreement',
#  b'Agreements',
#  b'Agri',
#  b'Agricola',
#  b'Agricole',
#  b'Agricoles',
#  b'Agricultural',
#  b'Agriculture',
#  b'Agriculture-ministry',
#  b'Agrippa',
#  b'Agro',
#  b'Agrobacterium',
#  b'Agua',
#  b'Aguais',
#  b'Aguiar',
#  b'Aguilar',
#  b'Aguirre',
#  b'Aguirre-Sacasa',
#  b'Agura',
#  b'Ahern',
#  b'Ahlerich',
#  b'Ahmad',
#  b'Ahmanson',
#  b'Ahmet',
#  b'Ahmiri',
#  b'Aho',
#  b'Ahold',
#  b'Ahoy',
#  b'Ahrens',
#  b'Ahsan',
#  b'Ai-',
#  b'Aichi',
#  b'Aid',
#  b'Aida',
#  b'Aidan',
#  b'Aide',
#  b'Aiden',
#  b'Aides',
#  b'Aiding',
#  b'Aids',
#  b'Aikawa',
#  b'Aiken',
#  b'Aikin',
#  b'Aikman',
#  b'Ailes',
#  b'Ailey',
#  b'Ainsley',
#  b'Ainslie',
#  b'Ainsworth',
#  b'Ainu',
#  b'Air',
#  b'Air-freight',
#  b'Air-traffic',
#  b'AirCal',
#  b'AirMalta',
#  b'AirTran',
#  b'Airborne',
#  b'Airbus',
#  b'Aircoa',
#  b'Aircraft',
#  b'Airedale',
#  b'Aires',
#  b'Airfone',
#  b'Airfones',
#  b'Airgas',
#  b'Airlie',
#  b'Airline',
#  b'Airmail',
#  b'Airman',
#  b'Airpark',
#  b'Airplanes',
#  b'Airport',
#  b'Airports',
#  b'Ait-Laoussine',
#  b'Aitken',
#  b'Aiwa',
#  b'Aj.',
#  b'AjA',
#  b'AjB',
#  b'Ajax',
#  b'Ajinomoto',
#  b'Ajit',
#  b'Akademie',
#  b'Ake',
#  b'Akerfeldt',
#  b'Akers',
#  b'Akerson',
#  b'Akin',
#  b'Akio',
#  b'Akita',
#  b'Akiva',
#  b'Akron',
#  b'Akros',
#  b'Aktiebolaget',
#  b'Aktiengesellschaft',
#  b'Akzo',
#  b'Al',
#  b'Al-Chalabi',
#  b'Al-Faqih',
#  b'Al-Rowas',
#  b'Al-Sabah',
#  b'Al-Seyassah',
#  b'Ala',
#  b'Ala.',
#  b'Alabama',
#  b'Alabamans',
#  b'Alabamian',
#  b'Alacrity',
#  b'Aladdin',
#  b'Alagoas',
#  b'Alai',
#  b'Alain',
#  b'Alakshak',
#  b'Alameda',
#  b'Alamein',
#  b'Alamito',
#  b'Alamo',
#  b'Alamogordo',
#  b'Alamos',
#  b'Alan',
#  b'Alar',
#  b'Alarcon',
#  b'Alarm',
#  b'Alasdair',
#  b'Alaska',
#  b'Alastair',
#  b'Alastor',
#  b'Alba',
#  b'Albacore',
#  b'Albanese',
#  b'Albania',
#  b'Albanian',
#  b'Albany',
#  b'Alberding',
#  b'Alberg',
#  b'Albers',
#  b'Albert',
#  b'Alberta',
#  b'Albertine',
#  b'Alberto',
#  b'Albertson',
#  b'Albertville',
#  b'Albion',
#  b'Albrecht',
#  b'Albright',
#  b'Album',
#  b'Albuquerque',
#  b'Alcan',
#  b'Alcarria',
#  b'Alcatel',
#  b'Alcatraz',
#  b'Alcee',
#  b'Alceste',
#  b'Alcibiades',
#  b'Alco',
#  b'Alcoa',
#  b'Alcohol',
#  b'Alcoholic',
#  b'Alcorn',
#  b'Alcott',
#  b'Alda',
#  b'Alden',
#  b'Aldermen',
#  b'Alderson',
#  b'Aldo',
#  b'Aldomet',
#  b'Aldrich',
#  b'Aldridge',
#  b'Aldrin',
#  b'Aldus',
#  b'Alec',
#  b'Alejandro',
#  b'Aleksei',
#  b'Alemagna',
#  b'Alert',
#  b'Alesio',
#  b'Alessio',
#  b'Alex',
#  b'Alexander',
#  b'Alexandra',
#  b'Alexandre',
#  b'Alexandria',
#  b'Alexei',
#  b'Alexeyeva',
#  b'Alexia',
#  b'Alexis',
#  b'Alf',
#  b'Alfa',
#  b'Alferon',
#  b'Alfieri',
#  b'Alfons',
#  b'Alfonse',
#  b'Alfonso',
#  b'Alfred',
#  b'Alfredo',
#  b'Algemene',
#  b'Alger',
#  b'Algeria',
#  b'Algiers',
#  b'Algol',
#  b'Algom',
#  b'Algonquin',
#  b'Ali',
#  b'Aliah',
#  b'Aliber',
#  b'Alice',
#  b'Alicia',
#  b'Alida',
#  b'Alien',
#  b'Alienated',
#  b'Alienus',
#  b'Aliksanian',
#  b'Alisarda',
#  b'Alisky',
#  b'Alison',
#  b'Alistair',
#  b'Alito',
#  b'Alix',
#  b'Aljian',
#  b'Alkylate',
#  b'All-American',
#  b'All-Star',
#  b'All-Union',
#  b'All-You-Can-Eat',
#  b'Alla',
#  b'Allah',
#  b'Allan',
#  b'Allay',
#  b'Allday',
#  b'Allegany',
#  b'Alleghany',
#  b'Allegheny',
#  b'Allegiance',
#  b'Allegra',
#  b'Allegretti',
#  b'Allegro',
#  b'Allemands',
#  b'Allen',
#  b'Allen-film',
#  b'Allendale',
#  b'Allende',
#  b'Allenport',
#  b'Allentown',
#  b'Allergan',
#  b'Alley',
#  b'Allgemeine',
#  b'Alliance',
#  b'Alliant',
#  b'Allianz',
#  b'Allie',
#  b'Allied',
#  b'Allied-Lyons',
#  b'Allied-Signal',
#  b'Alligood',
#  b'Allingham',
#  b'Allis-Chalmers',
#  ...]

# %%
import fast
words = read_lines()
fast.t2bow(words)
# Out:
# [(8733587623715143684, 1),
#  (4842599486780342283, 1),
#  (11512552109288456204, 1),
#  (4513208660830060557, 1),
#  (6042198899520833583, 1),
#  (18166218558604707888, 1),
#  (4800991747391359030, 1),
#  (15062037141402421304, 1),
#  (14071506230949840953, 1),
#  (18210834886943443006, 1),
#  (2082951046981355584, 1),
#  (16011641530158155841, 1),
#  (8661804692820199490, 1),
#  (12413909657533679681, 1),
#  (2154475729971316804, 1),
#  (1067336811759011908, 1),
#  (6702751836023031877, 1),
#  (11553771419855489088, 1),
#  (11924603262568630344, 1),
#  (9879711627373185100, 1),
#  (5628827610638190669, 1),
#  (15775328138531440717, 1),
#  (5858909631741167695, 1),
#  (2737972810632923219, 1),
#  (10812585323302094934, 1),
#  (15513399423047174231, 1),
#  (7583660232311310423, 1),
#  (17264713639867975769, 1),
#  (4657494168082581593, 1),
#  (13723714184507426908, 1),
#  (1402603709290252381, 1),
#  (97687205078632553, 1),
#  (12453600060201764970, 1),
#  (12744436973656606833, 1),
#  (5963162292678428786, 1),
#  (14635569808338192508, 1),
#  (6483358021469210749, 1),
#  (14461535102513449085, 1),
#  (17263261872036251777, 1),
#  (14314742755266791555, 1),
#  (14493891110101715075, 1),
#  (9136421216026757256, 1),
#  (13530983636612810890, 1),
#  (2396807709890185354, 1),
#  (18405799404855888018, 1),
#  (2146413881911019669, 1),
#  (9840617169194453143, 1),
#  (15678976915468585112, 1),
#  (6524006137352554654, 1),
#  (630522527847549087, 1),
#  (835772519309904031, 1),
#  (2133525083672545446, 1),
#  (7329635123507628207, 1),
#  (10710129291526932656, 1),
#  (6874224858715261108, 1),
#  (7898044819112200372, 1),
#  (683516170242230454, 1),
#  (343940743322273977, 1),
#  (114170012507834556, 1),
#  (7068875555510159549, 1),
#  (17986511630523697343, 1),
#  (3438205665663387843, 1),
#  (11553307439802091716, 1),
#  (16263040005493229764, 1),
#  (14436713125813553350, 1),
#  (5971747194782484684, 1),
#  (17239554453958166732, 1),
#  (16224590062334773458, 1),
#  (6919443542464006356, 1),
#  (7111470278028298468, 1),
#  (8871179626004482276, 1),
#  (1028226667804494055, 1),
#  (14208138021600233705, 1),
#  (13674978253240535273, 1),
#  (4128633377052035305, 1),
#  (10024912225170491630, 1),
#  (585737538707130607, 1),
#  (666770370870118639, 1),
#  (7946519363227748594, 1),
#  (15442079591677036788, 1),
#  (18121089938713086198, 1),
#  (10112231735228893431, 1),
#  (15118233380184131836, 1),
#  (250807670629730558, 1),
#  (4119483862519384318, 1),
#  (13518256460832573697, 1),
#  ...]

# %%
# %%cython
# from __future__ import print_function
# cimport cython
# from libc.stdio cimport FILE, fopen, fseek, fclose, SEEK_END, SEEK_SET, ftell, fread, fgets, rewind
# from libc.stdlib cimport malloc, free
# from cpython.exc cimport PyErr_SetFromErrnoWithFilenameObject
# from libc.string cimport strcpy, strlen
# import string
#
# def read_file_py(filename):
#     cdef FILE* txt                  # File of interest */
#
#     # Open the file
#     p = fopen(filename, "r")
#     # get the length of the file
#     fseek(p, 0, SEEK_END)
#     file_size = ftell(p)
#     fseek(p, 0, SEEK_SET)
#     # allocate memory for reading in the file
#     contents = <char*>malloc(file_size*sizeof(char))
#     # read entire file into the struct
#     fread(contents, 1, file_size, p)
#     # close the file once it's read into the char array
#     fclose(p)
#     #temp = (<bytes>contents).decode('utf-8')
#     temp = <bytes>contents
#     punc = string.punctuation.encode()
#     temp = temp.translate(None, punc)
#     return temp.lower().split()

# %%
# %timeit read_file_py(b"scripts\\10-Things-I-Hate-About-You.txt")
# Out:
# 2.88 ms ± 166 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def clean(list words, dict nouns):
    # convert to hash
    # check to see if it is there
    # if it is not remove from list

# %%
from collections import Counter
words = read_file_py(b"scripts\\10-Things-I-Hate-About-You.txt")

# %timeit fast.t2bow(words)
# %timeit Counter(words)
# Out:
# 1.97 ms ± 41.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.28 ms ± 58.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Counter({b'if': 35,
#          b'toplocationhreflocationhref': 1,
#          b'written': 1,
#          b'by': 49,
#          b'karen': 1,
#          b'mccullah': 1,
#          b'lutz': 1,
#          b'amp': 1,
#          b'kirsten': 1,
#          b'smith': 1,
#          b'based': 1,
#          b'on': 125,
#          b'taming': 2,
#          b'of': 215,
#          b'the': 698,
#          b'shrew': 3,
#          b'william': 9,
#          b'shakespeare': 8,
#          b'revision': 1,
#          b'november': 1,
#          b'12': 1,
#          b'1997': 1,
#          b'welcome': 2,
#          b'to': 437,
#          b'padua': 4,
#          b'high': 8,
#          b'school': 23,
#          b'your': 74,
#          b'typical': 1,
#          b'urbansuburban': 1,
#          b'in': 208,
#          b'portland': 1,
#          b'oregon': 1,
#          b'smarties': 1,
#          b'skids': 1,
#          b'preppies': 1,
#          b'granolas': 1,
#          b'loners': 1,
#          b'lovers': 1,
#          b'and': 401,
#          b'out': 114,
#          b'crowd': 12,
#          b'rub': 1,
#          b'sleep': 6,
#          b'their': 29,
#          b'eyes': 16,
#          b'head': 25,
#          b'for': 98,
#          b'main': 1,
#          b'building': 2,
#          b'kat': 187,
#          b'stratford': 10,
#          b'eighteen': 2,
#          b'pretty': 8,
#          b'but': 68,
#          b'trying': 5,
#          b'hard': 3,
#          b'not': 84,
#          b'be': 47,
#          b'a': 495,
#          b'baggy': 1,
#          b'granny': 1,
#          b'dress': 10,
#          b'glasses': 8,
#          b'balances': 1,
#          b'cup': 3,
#          b'coffee': 10,
#          b'backpack': 2,
#          b'as': 113,
#          b'she': 175,
#          b'climbs': 2,
#          b'her': 303,
#          b'battered': 2,
#          b'baby': 2,
#          b'blue': 3,
#          b'75': 1,
#          b'dodge': 1,
#          b'dart': 2,
#          b'stray': 4,
#          b'skateboard': 3,
#          b'clips': 1,
#          b'causing': 1,
#          b'stumble': 1,
#          b'spill': 1,
#          b'well': 21,
#          b'contents': 1,
#          b'young': 1,
#          b'rider': 1,
#          b'dashes': 1,
#          b'over': 34,
#          b'help': 4,
#          b'trembling': 1,
#          b'when': 41,
#          b'he': 193,
#          b'sees': 10,
#          b'who': 53,
#          b'his': 116,
#          b'board': 2,
#          b'has': 21,
#          b'hit': 4,
#          b'hey': 20,
#          b'sorry': 5,
#          b'cowering': 1,
#          b'fear': 3,
#          b'attempts': 4,
#          b'scoop': 1,
#          b'up': 116,
#          b'scattered': 1,
#          b'belongings': 1,
#          b'leave': 11,
#          b'it': 150,
#          b'persists': 1,
#          b'i': 321,
#          b'said': 5,
#          b'grabs': 16,
#          b'uses': 4,
#          b'shove': 1,
#          b'him': 96,
#          b'against': 7,
#          b'car': 22,
#          b'tip': 1,
#          b'throat': 4,
#          b'whimpers': 1,
#          b'pitifully': 1,
#          b'lets': 16,
#          b'go': 63,
#          b'path': 2,
#          b'clears': 3,
#          b'marches': 3,
#          b'through': 17,
#          b'pack': 1,
#          b'fearful': 1,
#          b'students': 7,
#          b'slams': 8,
#          b'open': 11,
#          b'door': 43,
#          b'entering': 2,
#          b'bianca': 131,
#          b'beautiful': 8,
#          b'sophomore': 5,
#          b'stands': 26,
#          b'facing': 2,
#          b'mirror': 4,
#          b'applying': 1,
#          b'lipstick': 1,
#          b'less': 2,
#          b'extraordinary': 1,
#          b'still': 16,
#          b'cute': 3,
#          b'friend': 7,
#          b'chastity': 28,
#          b'next': 27,
#          b'did': 17,
#          b'you': 409,
#          b'change': 3,
#          b'hair': 19,
#          b'no': 53,
#          b'might': 7,
#          b'wanna': 7,
#          b'think': 40,
#          b'about': 41,
#          b'girls': 13,
#          b'room': 15,
#          b'enter': 5,
#          b'hallway': 4,
#          b'is': 111,
#          b'immediately': 1,
#          b'greeted': 3,
#          b'an': 42,
#          b'admiring': 1,
#          b'both': 7,
#          b'boys': 8,
#          b'alike': 1,
#          b'awesome': 1,
#          b'shoes': 2,
#          b'greetings': 1,
#          b'continue': 5,
#          b'remains': 4,
#          b'wordless': 1,
#          b'unaddressed': 1,
#          b'side': 12,
#          b'smiles': 22,
#          b'proudly': 3,
#          b'acknowledging': 1,
#          b'fans': 2,
#          b'cameron': 99,
#          b'james': 1,
#          b'cleancut': 1,
#          b'easygoing': 1,
#          b'senior': 4,
#          b'with': 155,
#          b'farmboy': 1,
#          b'face': 23,
#          b'sits': 32,
#          b'miss': 11,
#          b'perky': 9,
#          b'impossibly': 1,
#          b'cheery': 1,
#          b'guidance': 2,
#          b'counselor': 1,
#          b'im': 74,
#          b'sure': 14,
#          b'wont': 11,
#          b'find': 12,
#          b'any': 18,
#          b'different': 4,
#          b'than': 11,
#          b'old': 6,
#          b'same': 4,
#          b'little': 15,
#          b'asswipe': 1,
#          b'motherfuckers': 1,
#          b'everywhere': 2,
#          b'plastic': 3,
#          b'smile': 23,
#          b'never': 26,
#          b'leaves': 3,
#          b'fidgets': 2,
#          b'chair': 6,
#          b'uncomfortably': 2,
#          b'questions': 1,
#          b'dont': 57,
#          b'so': 68,
#          b'maam': 1,
#          b'then': 71,
#          b'forth': 1,
#          b'scoot': 1,
#          b'ive': 14,
#          b'got': 24,
#          b'deviants': 1,
#          b'see': 19,
#          b'rises': 9,
#          b'makes': 18,
#          b'eye': 5,
#          b'contact': 2,
#          b'patrick': 145,
#          b'verona': 12,
#          b'sullenlooking': 1,
#          b'bad': 4,
#          b'ass': 7,
#          b'waits': 2,
#          b'outside': 8,
#          b'ms': 7,
#          b'perkys': 2,
#          b'slouch': 1,
#          b'smirk': 2,
#          b'let': 20,
#          b'us': 7,
#          b'know': 66,
#          b'how': 20,
#          b'cool': 7,
#          b'looks': 76,
#          b'down': 37,
#          b'at': 156,
#          b'file': 1,
#          b'were': 31,
#          b'making': 9,
#          b'our': 7,
#          b'visits': 1,
#          b'weekly': 1,
#          b'ritual': 1,
#          b'gives': 15,
#          b'withering': 2,
#          b'glance': 3,
#          b'answers': 1,
#          b'charming': 3,
#          b'missed': 1,
#          b'says': 9,
#          b'here': 17,
#          b'exposed': 1,
#          b'yourself': 7,
#          b'group': 5,
#          b'freshmen': 1,
#          b'was': 37,
#          b'bratwurst': 1,
#          b'eating': 4,
#          b'lunch': 2,
#          b'teeth': 2,
#          b'zipper': 1,
#          b'motions': 7,
#          b'office': 5,
#          b'shuffles': 1,
#          b'bumping': 1,
#          b'into': 33,
#          b'michael': 65,
#          b'eckman': 1,
#          b'lanky': 1,
#          b'brainy': 1,
#          b'will': 6,
#          b'either': 2,
#          b'end': 9,
#          b'politician': 1,
#          b'or': 13,
#          b'game': 5,
#          b'show': 7,
#          b'host': 1,
#          b'new': 13,
#          b'guy': 18,
#          b'they': 53,
#          b'tell': 19,
#          b'me': 116,
#          b'cmon': 7,
#          b'supposed': 7,
#          b'give': 7,
#          b'tour': 2,
#          b'which': 5,
#          b'dakota': 1,
#          b'from': 59,
#          b'north': 1,
#          b'actually': 7,
#          b'howd': 4,
#          b'kidding': 4,
#          b'people': 20,
#          b'live': 3,
#          b'there': 27,
#          b'yeah': 21,
#          b'couple': 5,
#          b'outnumbered': 1,
#          b'cows': 1,
#          b'though': 2,
#          b'many': 4,
#          b'thirtytwo': 1,
#          b'get': 49,
#          b'thousand': 3,
#          b'most': 7,
#          b'them': 29,
#          b'evil': 5,
#          b'prom': 13,
#          b'posters': 2,
#          b'adorn': 3,
#          b'wall': 5,
#          b'steers': 1,
#          b'points': 12,
#          b'various': 5,
#          b'cliques': 4,
#          b'weve': 4,
#          b'basic': 1,
#          b'unless': 4,
#          b'talk': 16,
#          b'first': 2,
#          b'bother': 2,
#          b'pass': 5,
#          b'full': 7,
#          b'jockcheerleader': 1,
#          b'splendor': 1,
#          b'those': 4,
#          b're': 6,
#          b'cowboys': 7,
#          b'several': 10,
#          b'stetsonwearing': 1,
#          b'big': 19,
#          b'belt': 2,
#          b'buckle': 1,
#          b'wrangler': 1,
#          b'guys': 17,
#          b'walk': 11,
#          b'that': 123,
#          b'used': 4,
#          b'these': 5,
#          b'have': 59,
#          b'seen': 4,
#          b'horse': 1,
#          b'just': 60,
#          b'jack': 1,
#          b'off': 33,
#          b'clint': 1,
#          b'eastwood': 1,
#          b'espresso': 1,
#          b'cart': 1,
#          b'teens': 3,
#          b'huddled': 1,
#          b'around': 23,
#          b'right': 30,
#          b'we': 47,
#          b'kids': 9,
#          b'very': 11,
#          b'edgy': 1,
#          b'make': 18,
#          b'sudden': 1,
#          b'movements': 1,
#          b'continues': 6,
#          b'delusionals': 1,
#          b'are': 46,
#          b'white': 17,
#          b'rastae': 1,
#          b'dreadlocks': 1,
#          b'jamaican': 2,
#          b'knit': 1,
#          b'berets': 1,
#          b'lounge': 1,
#          b'grass': 2,
#          b'cloud': 2,
#          b'pot': 3,
#          b'smoke': 3,
#          b'hovers': 1,
#          b'above': 3,
#          b'marley': 1,
#          b'theyre': 12,
#          b'black': 6,
#          b'semipolitical': 1,
#          b'mostly': 4,
#          b'watch': 13,
#          b'lot': 6,
#          b'wild': 2,
#          b'kingdom': 1,
#          b'what': 79,
#          b'mean': 10,
#          b'waves': 2,
#          b'derek': 5,
#          b'one': 37,
#          b'longest': 1,
#          b'dreads': 1,
#          b'save': 1,
#          b'some': 26,
#          b'after': 11,
#          b'bub': 1,
#          b'my': 83,
#          b'brother': 5,
#          b'peace': 2,
#          b'turns': 32,
#          b'follow': 3,
#          b'cafeteria': 3,
#          b'where': 12,
#          b'do': 58,
#          b'fit': 2,
#          b'all': 34,
#          b'this': 74,
#          b'loud': 3,
#          b'music': 8,
#          b'studiouslooking': 1,
#          b'future': 3,
#          b'mbas': 1,
#          b'ivy': 1,
#          b'league': 1,
#          b'already': 5,
#          b'accepted': 1,
#          b'someday': 1,
#          b'ill': 11,
#          b'sipping': 2,
#          b'merlot': 1,
#          b'while': 7,
#          b'table': 6,
#          b'jocks': 4,
#          b'torture': 3,
#          b'passersby': 1,
#          b'fixing': 1,
#          b'saab': 1,
#          b'yuppie': 1,
#          b'greed': 1,
#          b'back': 53,
#          b'alligator': 2,
#          b'shirt': 6,
#          b'stops': 8,
#          b'listening': 3,
#          b'walks': 38,
#          b'slo': 1,
#          b'mo': 1,
#          b'pure': 2,
#          b'perfect': 2,
#          b'passes': 2,
#          b'without': 9,
#          b'look': 41,
#          b'smitten': 2,
#          b'girl': 24,
#          b'burn': 1,
#          b'pine': 1,
#          b'perish': 1,
#          b'even': 27,
#          b'why': 23,
#          b'could': 19,
#          b'start': 13,
#          b'haircut': 1,
#          b'doesnt': 20,
#          b'matter': 5,
#          b'shes': 25,
#          b'allowed': 2,
#          b'date': 18,
#          b'until': 7,
#          b'older': 1,
#          b'sister': 23,
#          b'does': 14,
#          b'thats': 27,
#          b'impossibility': 1,
#          b'bored': 2,
#          b'seniors': 1,
#          b'doodle': 1,
#          b'scare': 2,
#          b'space': 1,
#          b'blaise': 9,
#          b'onestepawayfrommedication': 1,
#          b'english': 3,
#          b'teacher': 6,
#          b'tries': 17,
#          b'remember': 4,
#          b'talking': 6,
#          b'oh': 17,
#          b'yes': 7,
#          b'guess': 13,
#          b'analysis': 1,
#          b'man': 16,
#          b'sea': 2,
#          b'other': 29,
#          b'comments': 1,
#          b'saw': 3,
#          b'entered': 1,
#          b'slowly': 11,
#          b'cakes': 1,
#          b'speaks': 3,
#          b'didnt': 25,
#          b'read': 12,
#          b'hardy': 1,
#          b'book': 8,
#          b'fishing': 1,
#          b'habit': 1,
#          b'exactly': 5,
#          b'crucial': 1,
#          b'topic': 2,
#          b'roll': 1,
#          b'frankly': 1,
#          b'baffled': 1,
#          b'revere': 1,
#          b'hemingway': 1,
#          b'abusive': 1,
#          b'alcoholic': 1,
#          b'misogynist': 1,
#          b'had': 18,
#          b'cats': 1,
#          b'joey': 74,
#          b'dorsey': 12,
#          b'wellmuscled': 1,
#          b'jock': 8,
#          b'great': 7,
#          b'cheekbones': 1,
#          b'fun': 6,
#          b'row': 5,
#          b'opposed': 2,
#          b'bitter': 1,
#          b'selfrighteous': 1,
#          b'hag': 1,
#          b'friends': 4,
#          b'few': 13,
#          b'giggles': 4,
#          b'ignores': 3,
#          b'practiced': 1,
#          b'gesture': 2,
#          b'enough': 7,
#          b'mr': 19,
#          b'really': 18,
#          b'gets': 10,
#          b'fired': 1,
#          b'now': 27,
#          b'thinks': 6,
#          b'because': 18,
#          b'hemingways': 1,
#          b'male': 1,
#          b'asshole': 4,
#          b'hes': 33,
#          b'worthy': 1,
#          b'time': 24,
#          b'fighting': 1,
#          b'pill': 1,
#          b'box': 2,
#          b'colette': 1,
#          b'charlotte': 1,
#          b'bronte': 1,
#          b'simone': 1,
#          b'de': 1,
#          b'beauvoir': 1,
#          b'lounging': 1,
#          b'seat': 9,
#          b'elbows': 3,
#          b'crustylooking': 1,
#          b'crony': 1,
#          b'identified': 1,
#          b'name': 5,
#          b'scurvy': 8,
#          b'embroidered': 1,
#          b'workshirt': 1,
#          b'mother': 2,
#          b'goose': 1,
#          b'class': 8,
#          b'titters': 1,
#          b'wears': 2,
#          b'expression': 5,
#          b'intolerance': 1,
#          b'before': 17,
#          b'katarina': 6,
#          b'youve': 8,
#          b'been': 12,
#          b'terrorizing': 1,
#          b'again': 20,
#          b'expressing': 1,
#          b'opinion': 1,
#          b'terrorist': 1,
#          b'action': 3,
#          b'compared': 1,
#          b'choices': 2,
#          b'year': 10,
#          b'todays': 1,
#          b'events': 1,
#          b'quite': 4,
#          b'mild': 1,
#          b'way': 25,
#          b'bobby': 1,
#          b'rictors': 1,
#          b'gonad': 1,
#          b'retrieval': 1,
#          b'operation': 2,
#          b'went': 5,
#          b'case': 4,
#          b'youre': 73,
#          b'interested': 2,
#          b'maintain': 1,
#          b'kicked': 1,
#          b'himself': 6,
#          b'balls': 1,
#          b'merely': 1,
#          b'spectator': 1,
#          b'point': 6,
#          b'perceive': 1,
#          b'somewhat': 1,
#          b'daring': 2,
#          b'say': 23,
#          b'tempestuous': 1,
#          b'believe': 2,
#          b'heinous': 1,
#          b'bitch': 5,
#          b'term': 1,
#          b'often': 1,
#          b'grimaces': 2,
#          b'referring': 1,
#          b'medical': 1,
#          b'condition': 1,
#          b'want': 28,
#          b'work': 2,
#          b'matching': 1,
#          b'counselors': 1,
#          b'always': 14,
#          b'thank': 4,
#          b'excellent': 1,
#          b'droning': 1,
#          b'writes': 1,
#          b'note': 5,
#          b'flowing': 1,
#          b'handwriting': 1,
#          b'realize': 5,
#          b'language': 1,
#          b'bit': 3,
#          b'daunting': 1,
#          b'doing': 14,
#          b'best': 4,
#          b'folds': 1,
#          b'behind': 12,
#          b'flip': 1,
#          b'opens': 10,
#          b'reads': 2,
#          b'frowns': 2,
#          b'herself': 5,
#          b'care': 9,
#          b'comment': 3,
#          b'far': 4,
#          b'daddys': 1,
#          b'shakes': 2,
#          b'mandella': 43,
#          b'waiflike': 1,
#          b'slit': 2,
#          b'wrist': 2,
#          b'spiral': 1,
#          b'notebook': 3,
#          b'raises': 4,
#          b'hand': 22,
#          b'since': 6,
#          b'assisting': 1,
#          b'assuming': 3,
#          b'assignment': 1,
#          b'uh': 4,
#          b'whole': 6,
#          b'play': 5,
#          b'folio': 1,
#          b'plays': 3,
#          b'every': 8,
#          b'havent': 5,
#          b'challenging': 1,
#          b'eyebrow': 3,
#          b'stunned': 3,
#          b'answer': 9,
#          b'goes': 10,
#          b'call': 5,
#          b'student': 2,
#          b'sit': 12,
#          b'quiet': 3,
#          b'corner': 4,
#          b'carton': 1,
#          b'yogurt': 2,
#          b'gusto': 1,
#          b'amazingly': 2,
#          b'shell': 4,
#          b'idea': 5,
#          b'attacks': 1,
#          b'fact': 4,
#          b'cutting': 1,
#          b'gym': 5,
#          b'can': 36,
#          b'ta': 1,
#          b'hear': 11,
#          b'itself': 1,
#          b'ask': 10,
#          b'kats': 12,
#          b'attention': 7,
#          b'caught': 1,
#          b'lighting': 1,
#          b'cigarette': 4,
#          b'notices': 1,
#          b'staring': 6,
#          b'whos': 6,
#          b'random': 2,
#          b'skid': 1,
#          b'pat': 3,
#          b'gone': 3,
#          b'heard': 8,
#          b'porn': 2,
#          b'movies': 1,
#          b'completely': 12,
#          b'incapable': 1,
#          b'anything': 7,
#          b'interesting': 1,
#          b'block': 2,
#          b'e': 2,
#          b'forces': 1,
#          b'mandellas': 8,
#          b'eat': 1,
#          b'starving': 1,
#          b'slow': 4,
#          b'die': 2,
#          b'eats': 2,
#          b'whats': 18,
#          b'attempted': 1,
#          b'stares': 19,
#          b'expressionless': 1,
#          b'men': 3,
#          b'fine': 6,
#          b'institution': 1,
#          b'severely': 2,
#          b'lacking': 1,
#          b'killing': 1,
#          b'beyond': 2,
#          b'scope': 2,
#          b'normal': 6,
#          b'teenage': 3,
#          b'obsessions': 1,
#          b'venturing': 1,
#          b'past': 7,
#          b'daytime': 1,
#          b'fodder': 1,
#          b'world': 3,
#          b'need': 16,
#          b'expensive': 2,
#          b'therapy': 3,
#          b'imagine': 2,
#          b'things': 4,
#          b'hed': 2,
#          b'during': 2,
#          b'sex': 2,
#          b'minute': 7,
#          b'okay': 17,
#          b'kill': 4,
#          b'wherever': 1,
#          b'gonna': 11,
#          b'dace': 1,
#          b'ninety': 1,
#          b'pound': 1,
#          b'compulsive': 1,
#          b'failed': 1,
#          b'volleyball': 2,
#          b'struck': 2,
#          b'parade': 1,
#          b'cohorts': 4,
#          b'virgin': 1,
#          b'alert': 1,
#          b'lookin': 3,
#          b'good': 20,
#          b'ladies': 5,
#          b'coyest': 1,
#          b'watching': 11,
#          b'tragic': 1,
#          b'respond': 2,
#          b'observe': 1,
#          b'joeys': 11,
#          b'leers': 1,
#          b'bench': 1,
#          b'another': 13,
#          b'cue': 1,
#          b'beans': 1,
#          b'linger': 1,
#          b'like': 64,
#          b'bred': 1,
#          b'mothers': 1,
#          b'liked': 1,
#          b'grandmothers': 3,
#          b'gene': 1,
#          b'pool': 2,
#          b'rarely': 1,
#          b'diluted': 1,
#          b'shiteating': 1,
#          b'grin': 5,
#          b'permashitgrin': 1,
#          b'wish': 3,
#          b'moron': 2,
#          b'number': 4,
#          b'twelve': 1,
#          b'model': 2,
#          b'regional': 1,
#          b'stuff': 5,
#          b'rumored': 1,
#          b'tube': 2,
#          b'sock': 2,
#          b'ad': 2,
#          b'coming': 1,
#          b'bell': 3,
#          b'rings': 6,
#          b'stand': 3,
#          b'spit': 1,
#          b'empty': 5,
#          b'bean': 1,
#          b'cans': 2,
#          b'rise': 1,
#          b'catch': 4,
#          b'glimpse': 1,
#          b'inside': 8,
#          b'french': 5,
#          b'moms': 1,
#          b'canada': 1,
#          b'signed': 1,
#          b'tutor': 1,
#          b'id': 14,
#          b'chance': 1,
#          b'consecrate': 1,
#          b'watches': 15,
#          b'flounces': 1,
#          b'toward': 21,
#          b'pulls': 23,
#          b'beside': 2,
#          b'viper': 3,
#          b'vintage': 3,
#          b'reading': 6,
#          b'sassy': 1,
#          b'noticed': 2,
#          b'only': 17,
#          b'part': 5,
#          b'featured': 1,
#          b'kmart': 1,
#          b'spread': 2,
#          b'elbow': 1,
#          b'tough': 1,
#          b'break': 4,
#          b'practically': 3,
#          b'spitting': 2,
#          b'running': 3,
#          b'rest': 5,
#          b'month': 2,
#          b'zooms': 1,
#          b'away': 40,
#          b'yanks': 1,
#          b'ties': 2,
#          b'silk': 2,
#          b'scarf': 3,
#          b'convertible': 1,
#          b'incredibly': 3,
#          b'foul': 1,
#          b'slows': 2,
#          b'bus': 1,
#          b'ride': 4,
#          b'cant': 20,
#          b'fast': 1,
#          b'lowers': 1,
#          b'sunglasses': 1,
#          b'development': 1,
#          b'reaches': 3,
#          b'puts': 9,
#          b'tape': 4,
#          b'deck': 1,
#          b'sounds': 6,
#          b'joyful': 2,
#          b'punk': 7,
#          b'rock': 3,
#          b'fill': 1,
#          b'pull': 4,
#          b'crosses': 2,
#          b'front': 10,
#          b'moped': 1,
#          b'slam': 2,
#          b'brakes': 1,
#          b'keep': 6,
#          b'hitting': 3,
#          b'remove': 2,
#          b'sphincter': 1,
#          b'pedal': 1,
#          b'begins': 1,
#          b'fearfully': 1,
#          b'pedaling': 1,
#          b'peels': 4,
#          b'angry': 5,
#          b'delay': 1,
#          b'rushes': 6,
#          b'stop': 4,
#          b'minor': 1,
#          b'encounter': 1,
#          b'biancas': 6,
#          b'mewling': 1,
#          b'rampalian': 1,
#          b'wretch': 1,
#          b'putters': 1,
#          b'leaving': 8,
#          b'dodging': 1,
#          b'patricks': 9,
#          b'grimy': 1,
#          b'grey': 1,
#          b'jeep': 3,
#          b'vehicle': 1,
#          b'years': 2,
#          b'paint': 7,
#          b'jobs': 1,
#          b'its': 41,
#          b'former': 1,
#          b'glory': 1,
#          b'regulation': 1,
#          b'mail': 3,
#          b'truck': 3,
#          b'sideswipes': 1,
#          b'cars': 1,
#          b'sharon': 11,
#          b'attractive': 1,
#          b'focused': 1,
#          b'computer': 3,
#          b'typing': 2,
#          b'quickly': 6,
#          b'shelf': 1,
#          b'holds': 10,
#          b'bodiceripper': 1,
#          b'romance': 3,
#          b'novels': 1,
#          b'bearing': 2,
#          b'shoulder': 7,
#          b'types': 1,
#          b'undulating': 1,
#          b'desire': 2,
#          b'adrienne': 1,
#          b'removes': 1,
#          b'crimson': 1,
#          b'cape': 1,
#          b'revealing': 2,
#          b'creamy': 1,
#          b'walter': 22,
#          b'blustery': 1,
#          b'mad': 1,
#          b'scientisttype': 1,
#          b'obstetrician': 1,
#          b'enters': 13,
#          b'wearing': 9,
#          b'doctors': 1,
#          b'jacket': 2,
#          b'carrying': 2,
#          b'bag': 5,
#          b'hope': 3,
#          b'dinners': 1,
#          b'ready': 5,
#          b'ten': 1,
#          b'minutes': 3,
#          b'mrs': 5,
#          b'johnson': 1,
#          b'squirts': 2,
#          b'screamer': 1,
#          b'rifles': 1,
#          b'bends': 2,
#          b'kiss': 10,
#          b'cheek': 5,
#          b'microwave': 1,
#          b'anyone': 7,
#          b'cry': 3,
#          b'today': 1,
#          b'sadly': 1,
#          b'fourthirty': 1,
#          b'whereve': 1,
#          b'nowhere': 1,
#          b'hi': 7,
#          b'daddy': 12,
#          b'kisses': 7,
#          b'hello': 3,
#          b'precious': 3,
#          b'heads': 6,
#          b'stairs': 5,
#          b'touching': 1,
#          b'letter': 1,
#          b'sarah': 5,
#          b'lawrence': 5,
#          b'snatches': 1,
#          b'synonym': 1,
#          b'throbbing': 1,
#          b'country': 1,
#          b'thought': 21,
#          ...})

# %%
# %%cython
# from __future__ import print_function
# import numpy as np
# cimport numpy as cnp
#
# cnp.import_array()  # needed to initialize numpy-API
#
# #cpdef return_empty():
# #    cdef cnp.npy_intp dim = 10
# #    return cnp.PyArray_ZEROS(1, &dim, cnp.NPY_INT32,1)
#
# def return_empty():
#     cdef cnp.ndarray[cnp.int_t, ndim=1, mode='c'] data
#     data = np.zeros(10, dtype=int)
#
#     cdef unsigned int* buff = <unsigned int*>data
#     print(data)
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# def return_empty():
#     cdef cnp.ndarray[cnp.int_t, ndim=1] data
#     data = np.zeros(10, dtype=int)
#
#     cdef unsigned int* buff = <unsigned int*>data
#                              ^
# ------------------------------------------------------------
#
# C:\Users\znowak\.ipython\cython\_cython_magic_dce949eaebc93616c84d1bf1a55d8f0c.pyx:15:30: Python objects cannot be cast to pointers of primitive types

# %%
return_empty()
# Out:
# <class 'numpy.ndarray'>
