# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
#import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore")#,category=DeprecationWarning)
# Out:
# C:\Users\znowak\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
import os
from glob import glob

def get_file_names(foldername):
    cwd = os.getcwd()
    files = glob(cwd + f"\\{foldername}\\*.txt")
    files = [f"{foldername}\\"+os.path.basename(x) for x in files]
    return files

# %%
import tools

def noun_extraction_almawadie(foldername):
    noun_list = tools.read_lines()
    files = get_file_names(foldername)
    files = [bytes(file, 'utf-8') for file in files]
    
    res = tools.doc_to_list(files, noun_list)
    return res

# %%
data_words = noun_extraction_almawadie("scripts_small")
data_words = [[word.decode("utf") for word in page]for page in data_words]

# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['screenplay', 'sam', 'hamm', 'hells', 'christmas', 'weeks', 'snow', 'white', 'blanket', 'city', 'serene', 'peace', 'strangers', 'wave', 'salvation', 'army', 'ring', 'bells', 'as', 'night', 'falls', 'sign', 'broad_avenue', 'noel', 'shopping', 'days', 'left', 'christmas', 'streets', 'shoppers', 'souvenir', 'store', 'mom', 'squabbling', 'year', 'old', 'storefronts', 'batman', 'merchandise', 'key', 'chains', 'figurines', 'kid', 'batman', 'baseball', 'cap', 'little', 'black', 'cape', 'mom', 'store', 'window', 'scrap', 'metal', 'sign', 'reading', 'fragments', 'panhandler', 'entrance', 'his', 'array', 'jacket', 'sweatshirt', 'logo', 'winter', 'hours', 'blizzard', 'drifts', 'feet', 'deep', 'streets', 'cars', 'snow', 'plow', 'size', 'tank', 'frame', 'as', 'group', 'mufflers', 'weather', 'street', 'spreading', 'cheer', 'goodwill', 'lovely', 'rendition', 'silent', 'night', 'delivery', 'truck', 'snow', 'chains', 'wake', 'plow', 'sides', 'cartoon', 'advertising', 'popular', 'ice', 'cream', 'snack', 'polar', 'bars', 'time', 'year', 'santa', 'bell', 'bucket', 'waves', 'truck', 'as', 'rounds_corner', 'carol', 'explosion', 'rocks', 'street', 'sound', 'automatic', 'gunfire', 'high', 'security', 'alarm', 'corner', 'carnage', 'streets', 'windows', 'jewelry', 'store', 'security', 'guards', 'face', 'snow', 'as', 'robbers', 'white', 'camouflage', 'gear', 'glass', 'loot', 'spill', 'corner', 'spray', 'gunfire', 'panic', 'polar', 'bar', 'truck', 'jewelry', 'store', 'as', 'doors', 'open', 'ramp', 'slides', 'truck', 'robbers', 'scramble', 'seconds', 'slide', 'sirens', 'howl', 'police', 'car', 'corner', 'trifle', 'fast', 'street', 'drift', 'cops', 'gun', 'engine', 'wheels', 'snow', 'chase', 'foot', 'windshield', 'salvation', 'army', 'santa', 'hoisting', 'windshield', 'cops', 'sink', 'view', 'as', 'santa', 'races', 'loot', 'squad_cars', 'jewelry', 'store', 'carry', 'pursuit', 'snows', 'foot', 'deep', 'mph', 'cop_cars', 'skid', 'halt', 'snowplow', 'course', 'side', 'plow', 'sticking', 'sidewalks', 'sidewalks', 'hardy', 'souls', 'streets', 'diving', 'cover', 'couple', 'derelicts', 'fire', 'run', 'time', 'poke', 'heads', 'whizzes', 'inches', 'robbers', 'fan', 'directions',
#   ('answer', 2),
#   ('antenna', 1),
#   ('anticipation', 3),
#   ('antique', 1),
#   ('antiquity', 1),
#   ('apartment', 3),
#   ('ape', 1),
#   ('appearance', 1),
#   ('appliance', 1),
#   ('application', 1),
#   ('approach', 2),
#   ('apron', 2),
#   ('arc', 1),
#   ('arch', 1),
#   ('archaeologist', 1),
#   ('area', 1),
#   ('argument', 1),
#   ('arm', 36),
#   ('armor', 5),
#   ('armory', 3),
#   ('armpit', 1),
#   ('army', 3),
#   ('arraignment', 1),
#   ('array', 1),
#   ('arrest', 1),
#   ('arrival', 1),
#   ('art', 5),
#   ('artifact', 1),
#   ('ass', 2),
#   ('assault', 2),
#   ('assembly', 4),
#   ('assortment', 1),
#   ('astonishment', 4),
#   ('athleticism', 1),
#   ('atrium', 1),
#   ('attack', 2),
#   ('attacker', 1),
#   ('attempt', 1),
#   ('attendance', 1),
#   ('attendant', 1),
#   ('attention', 1),
#   ('attitude', 1),
#   ('attorney', 5),
#   ('authenticator', 1),
#   ('avenue', 1),
#   ('ax', 1),
#   ('baby', 1),
#   ('back', 3),
#   ('background', 1),
#   ('badge', 2),
#   ('bag', 7),
#   ('bait', 1),
#   ('balance', 3),
#   ('balcony', 7),
#   ('ball', 5),
#   ('band', 2),
#   ('bank', 9),
#   ('banner', 2),
#   ('bannister', 2),
#   ('bar', 14),
#   ('barrel', 2),
#   ('barrett', 6),
#   ('bartender', 2),
#   ('baseball', 4),
#   ('basement', 2),
#   ('basis', 1),
#   ('bat', 35),
#   ('bathroom', 1),
#   ('batman', 111),
#   ('batmobile', 27),
#   ('battery', 2),
#   ('batwing', 2),
#   ('bay', 3),
#   ('beacon', 1),
#   ('bead', 3),
#   ('beam', 8),
#   ('bear', 2),
#   ('beast', 1),
#   ('bed', 13),
#   ('bedpost', 1),
#   ('bedroom', 4),
#   ('bedside', 1),
#   ('beef', 1),
#   ('bell', 2),
#   ('belly', 2),
#   ('belonging', 3),
#   ('belt', 6),
#   ('bend', 4),
#   ('benefit', 1),
#   ('beret', 3),
#   ('bet', 2),
#   ('bewilderment', 1),
#   ('bg', 3),
#   ('bickering', 1),
#   ('biddy', 1),
#   ('bill', 5),
#   ('bird', 38),
#   ('bit', 3),
#   ('bitch', 2),
#   ('blackness', 1),
#   ('blade', 3),
#   ('blanket', 2),
#   ('blind', 2),
#   ('blip', 1),
#   ('blizzard', 1),
#   ('block', 14),
#   ('blood', 10),
#   ('blouse', 1),
#   ('blow', 4),
#   ('board', 7),
#   ('boat', 6),
#   ('boat_thug', 8),
#   ('body', 18),
#   ('bodyguard', 2),
#   ('bolt', 5),
#   ('bomb', 2),
#   ('bond', 2),
#   ('bondage', 3),
#   ('bone', 1),
#   ('boniface', 1),
#   ('book', 3),
#   ('bookcase', 2),
#   ('boot', 1),
#   ('booth', 2),
#   ('border', 1),
#   ('boss', 1),
#   ('bottle', 2),
#   ('bottom', 3),
#   ('boulder', 2),
#   ('bound', 2),
#   ('box', 28),
#   ('boy', 15),
#   ('bra', 1),
#   ('brace', 4),
#   ('bracelet', 1),
#   ('branch', 5),
#   ('brand', 1),
#   ('brass', 1),
#   ('break', 8),
#   ('breast', 1),
#   ('breath', 2),
#   ('breathing', 1),
#   ('brick', 2),
#   ('bridge', 6),
#   ('broadcast', 1),
#   ('bronze', 2),
#   ('brow', 2),
#   ('bruce', 169),
#   ('bruise', 1),
#   ('brush', 1),
#   ('bubble', 3),
#   ('buck', 2),
#   ('bucket', 1),
#   ('buddy', 2),
#   ('bug', 2),
#   ('building', 18),
#   ('bullet', 3),
#   ('bullion', 3),
#   ('bullock', 6),
#   ('bunch', 4),
#   ('bundle', 6),
#   ('bunk', 2),
#   ('burger', 1),
#   ('burrow', 1),
#   ('burst', 1),
#   ('bus', 5),
#   ('business', 6),
#   ('bust', 2),
#   ('bustle', 1),
#   ('butcher', 1),
#   ('butler', 6),
#   ('butt', 1),
#   ('button', 5),
#   ('buyin', 1),
#   ('buzzer', 1),
#   ('buzzsaw', 1),
#   ('bystander', 1),
#   ('cab', 1),
#   ('cabinet', 1),
#   ('cable', 4),
#   ('cadet', 1),
#   ('cage', 7),
#   ('call', 9),
#   ('camera', 23),
#   ('camouflage', 1),
#   ('camp', 2),
#   ('can', 1),
#   ('canary', 3),
#   ('canister', 1),
#   ('cap', 4),
#   ('cape', 11),
#   ('capitalization', 1),
#   ('capsule', 3),
#   ('car', 85),
#   ('card', 18),
#   ('cardboard', 3),
#   ('cardinal', 1),
#   ('cargo', 1),
#   ('carnage', 5),
#   ('carol', 2),
#   ('carpet', 4),
#   ('carrier', 1),
#   ('carry', 1),
#   ('cart', 3),
#   ('cartoon', 1),
#   ('cartwheel', 1),
#   ('case', 8),
#   ('cashmere', 1),
#   ('cat', 22),
#   ('catcall', 1),
#   ('catch', 2),
#   ('catering', 1),
#   ('cave', 7),
#   ('cavern', 6),
#   ('cd', 1),
#   ('ceiling', 8),
#   ('cell', 4),
#   ('center', 10),
#   ('century', 1),
#   ('ceremony', 1),
#   ('chain', 4),
#   ('chair', 7),
#   ('chamber', 2),
#   ('champagne', 1),
#   ('chance', 1),
#   ('chandelier', 4),
#   ('change', 5),
#   ('channel', 1),
#   ('chaos', 3),
#   ('chapel', 1),
#   ('charge', 4),
#   ('charlie', 1),
#   ('chase', 5),
#   ('check', 6),
#   ('cheek', 3),
#   ('cheer', 4),
#   ('chemical', 1),
#   ('cheshire', 1),
#   ('chest', 7),
#   ('chicken', 1),
#   ('child', 4),
#   ('chin', 3),
#   ('china', 1),
#   ('chop', 1),
#   ('christ', 1),
#   ('christma', 2),
#   ('christmas', 16),
#   ('chromium', 1),
#   ('chuckle', 8),
#   ('circle', 8),
#   ('circumstance', 1),
#   ('citizen', 5),
#   ('city', 26),
#   ('clamp', 1),
#   ('clang', 2),
#   ('class', 1),
#   ('claw', 4),
#   ('claws', 3),
#   ('cleaner', 1),
#   ('clearing', 3),
#   ('cleaver', 1),
#   ('client', 3),
#   ('clientele', 1),
#   ('climate', 1),
#   ('climber', 1),
#   ('clip', 2),
#   ('clipping', 3),
#   ('clock', 3),
#   ('closet', 1),
#   ('cloth', 2),
#   ('clothe', 1),
#   ('clothing', 1),
#   ('cloud', 1),
#   ('club', 3),
#   ('cluster', 6),
#   ('clutch', 2),
#   ('coat', 9),
#   ('cobblestone', 1),
#   ('cocaine', 1),
#   ('cocktail', 1),
#   ('coffee', 3),
#   ('colleague', 4),
#   ('collection', 1),
#   ('collector', 1),
#   ('colony', 1),
#   ('colossus', 1),
#   ('comment', 1),
#   ('commissioner', 8),
#   ('commotion', 2),
#   ('company', 1),
#   ('composure', 1),
#   ('computer', 2),
#   ('concern', 1),
#   ('concert', 1),
#   ('conclusion', 1),
#   ('condition', 1),
#   ('conference', 1),
#   ('conflict', 1),
#   ('confusion', 7),
#   ('consideration', 1),
#   ('consternation', 1),
#   ('construction', 7),
#   ('contact', 4),
#   ('contempt', 1),
#   ('content', 5),
#   ('context', 1),
#   ('contract', 1),
#   ('contribution', 1),
#   ('contributor', 1),
#   ('control', 6),
#   ('conversation', 4),
#   ('convict', 1),
#   ('convoy', 1),
#   ('cookie', 2),
#   ('coop', 1),
#   ('cop', 77),
#   ('copy', 1),
#   ('cord', 11),
#   ('corner', 23),
#   ('corpse', 4),
#   ('cost', 1),
#   ('costume', 2),
#   ('count', 2),
#   ('counterpart', 1),
#   ('country', 1),
#   ('county', 3),
#   ('couple', 13),
#   ('courage', 1),
#   ('course', 6),
#   ('court', 2),
#   ('courthouse', 1),
#   ('courtyard', 1),
#   ('cousin', 2),
#   ('cover', 3),
#   ('cowan', 1),
#   ('cpu', 1),
#   ('crack', 5),
#   ('cradle', 1),
#   ('crane', 1),
#   ('crash', 2),
#   ('crate', 8),
#   ('cream', 1),
#   ('creature', 1),
#   ('credit', 1),
#   ('creek', 2),
#   ('crest', 4),
#   ('crew', 1),
#   ('crime', 4),
#   ('crony', 2),
#   ('crotch', 1),
#   ('crowd', 10),
#   ('cruise', 5),
#   ('crunch', 1),
#   ('crusade', 1),
#   ('crust', 1),
#   ('crystal', 1),
#   ('cue', 2),
#   ('cup', 4),
#   ('curator', 2),
#   ('curiosity', 3),
#   ('curtain', 1),
#   ('custody', 1),
#   ('customer', 1),
#   ('cylinder', 3),
#   ('d', 10),
#   ('daddy', 3),
#   ('dance', 1),
#   ('dancing', 1),
#   ('danger', 4),
#   ('dark', 1),
#   ('darkness', 13),
#   ('dart', 3),
#   ('darts', 1),
#   ('dashboard', 3),
#   ('date', 4),
#   ('datum', 1),
#   ('day', 6),
#   ('daze', 1),
#   ('dealer', 1),
#   ('death', 1),
#   ('debt', 1),
#   ('deck', 8),
#   ('deep_breath', 3),
#   ('degree', 2),
#   ('delight', 1),
#   ('delivery', 9),
#   ('demolition', 1),
#   ('demon', 1),
#   ('demonstration', 1),
#   ('deposit', 1),
#   ('depredation', 1),
#   ('derelict', 3),
#   ('desk', 12),
#   ('despair', 1),
#   ('dessert', 1),
#   ('detail', 2),
#   ('development', 2),
#   ('device', 7),
#   ('diameter', 1),
#   ('diamond', 2),
#   ('dick', 12),
#   ('dick_grayson', 1),
#   ('difference', 1),
#   ('dig', 10),
#   ('dignity', 1),
#   ('dime', 1),
#   ('dining', 1),
#   ('dinner', 5),
#   ('dip', 1),
#   ('direction', 7),
#   ('disbelief', 4),
#   ('discussion', 1),
#   ('disk', 1),
#   ('dismay', 3),
#   ('display', 5),
#   ('disposal', 1),
#   ('distance', 16),
#   ('distinction', 1),
#   ('distress', 1),
#   ('disturbance', 1),
#   ('dive', 2),
#   ('diving', 3),
#   ('dock', 14),
#   ('doctor', 7),
#   ('dollar', 6),
#   ('domain', 1),
#   ('dome', 4),
#   ('dominance', 1),
#   ('donation', 1),
#   ('donut', 1),
#   ('door', 61),
#   ('doorbell', 1),
#   ('doorman', 1),
#   ('doorway', 9),
#   ('dot', 1),
#   ('doubt', 1),
#   ('downtown', 3),
#   ('dozen', 14),
#   ('drag', 3),
#   ('drain', 1),
#   ('drainage', 3),
#   ('drape', 2),
#   ('drawer', 7),
#   ('dress', 4),
#   ('dressing', 1),
#   ('drift', 5),
#   ('drink', 4),
#   ('drinking', 1),
#   ('drive', 2),
#   ('driver', 8),
#   ('droll', 1),
#   ('drone', 1),
#   ('drop', 7),
#   ('drug', 7),
#   ('drum', 1),
#   ('duck', 9),
#   ('duty', 1),
#   ('dwelling', 1),
#   ('dying', 1),
#   ('ear', 2),
#   ('earphone', 2),
#   ('earth', 1),
#   ('east', 3),
#   ('eavesdropping', 1),
#   ('echo', 7),
#   ('eddie', 1),
#   ('edge', 16),
#   ('edition', 2),
#   ('editor', 1),
#   ('effect', 2),
#   ('effort', 4),
#   ('egypt', 1),
#   ('elbow', 2),
#   ('element', 1),
#   ('elevator', 7),
#   ('eliot', 1),
#   ('elite', 1),
#   ('elliott', 2),
#   ('embarrassment', 1),
#   ('emblem', 1),
#   ('emergency', 3),
#   ('emotion', 1),
#   ('employee', 1),
#   ('end', 9),
#   ('enemy', 1),
#   ('engine', 5),
#   ('ensemble', 1),
#   ('entertainment', 1),
#   ('enthusiasm', 1),
#   ('entrance', 19),
#   ('entry_hall', 7),
#   ('envelope', 4),
#   ('equipment', 6),
#   ('estate', 1),
#   ('europe', 2),
#   ('eve', 2),
#   ('evening', 2),
#   ('event', 1),
#   ('evidence', 1),
#   ('example', 1),
#   ('exasperation', 1),
#   ('exception', 1),
#   ('exchange', 3),
#   ('excitement', 1),
#   ('exhibit', 3),
#   ('exhilaration', 1),
#   ('exit', 1),
#   ('expedition', 1),
#   ('expert', 2),
#   ('explosion', 3),
#   ('expression', 3),
#   ('extension', 1),
#   ('exterior', 1),
#   ('extract', 1),
#   ('eye', 45),
#   ('eyebrow', 2),
#   ('fabric', 1),
#   ('facade', 2),
#   ('face', 45),
#   ('fact', 1),
#   ('factory', 1),
#   ('falcon', 2),
#   ('fall', 1),
#   ('family', 11),
#   ('fan', 2),
#   ('fantasy', 1),
#   ('fascination', 1),
#   ('fashion', 1),
#   ('fat', 2),
#   ('fate', 1),
#   ('father', 6),
#   ('fault', 1),
#   ('fear', 2),
#   ('feather', 1),
#   ('feed', 3),
#   ('feeding', 2),
#   ('feeling', 2),
#   ('fender', 2),
#   ('fern', 1),
#   ('festivity', 1),
#   ('fiddle', 1),
#   ('figure', 18),
#   ('figurine', 2),
#   ('filament', 1),
#   ('file', 3),
#   ('film', 2),
#   ('fin', 3),
#   ('finding', 1),
#   ('finger', 9),
#   ('fire', 17),
#   ('fireplace', 4),
#   ('firework', 1),
#   ('fish', 1),
#   ('fist', 3),
#   ('fix', 1),
#   ('flame', 4),
#   ('flash', 5),
#   ('flashlight', 3),
#   ('fleet', 1),
#   ('flesh', 1),
#   ('flick', 4),
#   ('flicker', 1),
#   ('flight', 2),
#   ('fling', 5),
#   ('flirtation', 1),
#   ('flock', 4),
#   ('floodlight', 1),
#   ('floor', 28),
#   ('flutter', 1),
#   ('fly', 1),
#   ('flyer', 1),
#   ('focus', 1),
#   ('folder', 1),
#   ('folk', 1),
#   ('food', 3),
#   ('foot', 55),
#   ('footstep', 1),
#   ('force', 10),
#   ('forearm', 2),
#   ('fork', 1),
#   ('form', 2),
#   ('fortune', 5),
#   ('fountain', 1),
#   ('fracas', 1),
#   ('fragment', 2),
#   ('frame', 9),
#   ('freefall', 1),
#   ('frenzy', 4),
#   ('frequency', 1),
#   ('friend', 8),
#   ('fringe', 1),
#   ('front', 5),
#   ('fuck', 1),
#   ('fume', 2),
#   ('fun', 1),
#   ('fund', 2),
#   ('fur', 4),
#   ('furnishing', 1),
#   ('furniture', 1),
#   ('fury', 1),
#   ('fuse', 1),
#   ('gain', 1),
#   ('game', 1),
#   ('gang', 1),
#   ('gangplank', 3),
#   ('gap', 5),
#   ('garage', 1),
#   ('garb', 3),
#   ('garbage', 2),
#   ('garden', 1),
#   ('garfield', 1),
#   ('gas', 4),
#   ('gasp', 2),
#   ('gate', 4),
#   ('gaze', 3),
#   ('gear', 9),
#   ('gen', 2),
#   ('generation', 1),
#   ('generator', 2),
#   ('generosity', 2),
#   ('gentleman', 3),
#   ('germ', 1),
#   ('gesture', 12),
#   ('getaway', 2),
#   ('gift', 7),
#   ('giggle', 1),
#   ('girder', 1),
#   ('girl', 5),
#   ('girlfriend', 1),
#   ('glance', 9),
#   ('glass', 17),
#   ('glee', 1),
#   ('glimpse', 4),
#   ('globe', 7),
#   ('glow', 1),
#   ('god', 3),
#   ('goddess', 2),
#   ('gold', 5),
#   ('goodbye', 1),
#   ('goodwill', 1),
#   ('goon', 14),
#   ('gordon', 18),
#   ('gown', 1),
#   ('grab', 27),
#   ('grandfather', 2),
#   ('grandmas', 1),
#   ('grate', 6),
#   ('gratitude', 1),
#   ('gravel', 2),
#   ('greed', 1),
#   ('greeting', 1),
#   ('grid', 1),
#   ('gridlock', 1),
#   ('grief', 1),
#   ('grille', 1),
#   ('grimace', 1),
#   ('grin', 3),
#   ('grip', 5),
#   ('grit', 1),
#   ('ground', 12),
#   ('group', 3),
#   ('guarantee', 1),
#   ('guard', 39),
#   ('guardian', 2),
#   ('guess', 1),
#   ('guest', 5),
#   ('guide', 1),
#   ('guilt', 1),
#   ('gull', 1),
#   ('gullet', 1),
#   ('gun', 38),
#   ('gunfire', 4),
#   ('gunman', 1),
#   ('gunny', 1),
#   ('gunpoint', 1),
#   ('gunshot', 3),
#   ('gurgle', 1),
#   ('gut', 1),
#   ('guy', 12),
#   ('gymnast', 5),
#   ('hail', 1),
#   ('hair', 8),
#   ('hairdo', 1),
#   ('half', 2),
#   ('hall', 14),
#   ('hallway', 10),
#   ('halt', 1),
#   ('hamm', 1),
#   ('hand', 66),
#   ('handcuff', 3),
#   ('handful', 3),
#   ('handkerchief', 1),
#   ('harbor', 1),
#   ('harm', 1),
#   ('harrison', 2),
#   ('haste', 1),
#   ('hat', 3),
#   ('haul', 1),
#   ('head', 29),
#   ('headlight', 1),
#   ('headline', 3),
#   ('headphone', 1),
#   ('heap', 3),
#   ('heart', 2),
#   ('hearth', 1),
#   ('heating', 1),
#   ('heave', 1),
#   ('heaven', 1),
#   ('heel', 8),
#   ('height', 1),
#   ('helicopter', 6),
#   ('hell', 6),
#   ('heritage', 1),
#   ('hermione', 1),
#   ('hero', 3),
#   ('hesitation', 1),
#   ('hill', 5),
#   ('hillside', 1),
#   ('hinge', 1),
#   ('hint', 3),
#   ('hiring', 1),
#   ('history', 1),
#   ('hit', 4),
#   ('hitch', 1),
#   ('hmm', 1),
#   ('hockey', 1),
#   ('holding', 1),
#   ('hole', 3),
#   ('holiday', 3),
#   ('home', 3),
#   ('honey', 2),
#   ('hood', 2),
#   ('hoodlum', 1),
#   ('hook', 7),
#   ('hooker', 1),
#   ('hop', 4),
#   ('horizon', 1),
#   ('horn', 3),
#   ('horror', 8),
#   ('horse', 14),
#   ('horseback', 1),
#   ('host', 3),
#   ('hour', 5),
#   ('house', 11),
#   ('household', 1),
#   ('houseware', 1),
#   ('howl', 4),
#   ('hub', 1),
#   ('huddle', 3),
#   ('hug', 2),
#   ('hundred', 3),
#   ('hysteria', 1),
#   ('i', 3),
#   ('ice', 11),
#   ('idea', 4),
#   ('idiot', 5),
#   ('ii', 2),
#   ('illumination', 1),
#   ('image', 1),
#   ('imitation', 1),
#   ('impact', 2),
#   ('impression', 2),
#   ('impulse', 2),
#   ('inch', 8),
#   ('incident', 2),
#   ('inconvenience', 1),
#   ('indifference', 1),
#   ('industrialist', 2),
#   ('infatuation', 1),
#   ('inform', 1),
#   ('ingenuity', 1),
#   ('ink', 1),
#   ('insect', 1),
#   ('insert', 2),
#   ('inspection', 2),
#   ('inspiration', 2),
#   ('instant', 2),
#   ('instruction', 2),
#   ('instrument', 1),
#   ('insult', 1),
#   ('intention', 1),
#   ('interest', 4),
#   ('interrogation', 1),
#   ('intersection', 7),
#   ('interval', 1),
#   ('interview', 2),
#   ('intruder', 4),
#   ('invasion', 1),
#   ('invention', 1),
#   ('iron', 4),
#   ('island', 1),
#   ('issue', 4),
#   ('item', 1),
#   ('jack', 1),
#   ('jacket', 5),
#   ('jackson', 1),
#   ('jacob', 1),
#   ('jam', 2),
#   ('jar', 2),
#   ('jaw', 8),
#   ('jerk', 4),
#   ('jet', 3),
#   ('jewel', 1),
#   ('jewelry', 3),
#   ('jim', 3),
#   ('jitter', 1),
#   ('job', 2),
#   ('jogger', 2),
#   ('jogging', 1),
#   ('joke', 3),
#   ('jolt', 1),
#   ('journal', 1),
#   ('julio', 1),
#   ('jumping', 1),
#   ('junk', 1),
#   ('junkie', 1),
#   ('justice', 3),
#   ('kamikaze', 1),
#   ('kettle', 1),
#   ('keyboard', 1),
#   ('kick', 3),
#   ('kid', 30),
#   ('kind', 7),
#   ('king', 2),
#   ('kiosk', 1),
#   ('kiss', 4),
#   ('kitchen', 15),
#   ('kitten', 1),
#   ('kitty', 4),
#   ('knee', 2),
#   ('knife', 3),
#   ('knob', 1),
#   ('knot', 1),
#   ('kyle', 9),
#   ('lab', 5),
#   ('lace', 1),
#   ('lackey', 2),
#   ('ladder', 1),
#   ('lady', 5),
#   ('lake', 5),
#   ('lance', 1),
#   ('land', 14),
#   ('landing', 4),
#   ('landscape', 1),
#   ('language', 1),
#   ('lantern', 2),
#   ('lap', 1),
#   ('lapse', 1),
#   ('laugh', 4),
#   ('laughter', 1),
#   ('launcher', 2),
#   ('law', 1),
#   ('lbs', 1),
#   ('leap', 2),
#   ('leather', 2),
#   ('leave', 2),
#   ('ledge', 12),
#   ('leg', 12),
#   ('length', 2),
#   ('lens', 3),
#   ('letter', 9),
#   ('level', 6),
#   ('liberty', 1),
#   ('library', 7),
#   ('lid', 2),
#   ('lie', 2),
#   ('lieu', 1),
#   ('lieutenant', 3),
#   ('life', 14),
#   ('light', 21),
#   ('lighting', 1),
#   ('lightning', 1),
#   ('limb', 2),
#   ('limitation', 1),
#   ('limo', 1),
#   ('line', 8),
#   ('linen', 2),
#   ('lingerie', 1),
#   ('lion', 1),
#   ('lip', 7),
#   ('lipstick', 3),
#   ('liquor', 1),
#   ('liver', 1),
#   ('living', 2),
#   ('load', 3),
#   ('loading', 2),
#   ('location', 1),
#   ('lock', 2),
#   ('logic', 1),
#   ('logo', 1),
#   ('longshoreman', 1),
#   ('loop', 2),
#   ('loot', 3),
#   ('lot', 7),
#   ('loudspeaker', 1),
#   ('love', 4),
#   ('luck', 3),
#   ('lung', 1),
#   ('luxury', 1),
#   ('mace', 1),
#   ('machine', 1),
#   ('madman', 1),
#   ('magazine', 1),
#   ('magnate', 4),
#   ('magnet', 1),
#   ('magnification', 1),
#   ('mahogany', 1),
#   ('mail', 4),
#   ('makeover', 1),
#   ('makeup', 1),
#   ('malice', 1),
#   ('man', 30),
#   ('manager', 1),
#   ('managing', 1),
#   ('maneuver', 1),
#   ('manor', 4),
#   ('map', 1),
#   ('marble', 1),
#   ('marche', 12),
#   ('marcher', 3),
#   ('marching', 2),
#   ('markdown', 1),
#   ('mask', 12),
#   ('mass', 2),
#   ('massacre', 2),
#   ('massage', 1),
#   ('master', 6),
#   ('matter', 1),
#   ('maze', 1),
#   ('meat', 1),
#   ('meeting', 1),
#   ('melee', 1),
#   ('member', 9),
#   ('menace', 1),
#   ('merchandise', 3),
#   ('merry_christma', 3),
#   ('mess', 4),
#   ('message', 4),
#   ('metal', 11),
#   ('method', 1),
#   ('michelangelo', 1),
#   ('microphone', 1),
#   ('midair', 5),
#   ('midnight', 2),
#   ('midst', 4),
#   ('midstream', 1),
#   ('midway', 1),
#   ('mike', 10),
#   ('mile', 1),
#   ('mill', 2),
#   ('milling', 1),
#   ('million', 1),
#   ('millionaire', 3),
#   ('mind', 9),
#   ('mine', 2),
#   ('mineral', 1),
#   ('minute', 4),
#   ('mirror', 1),
#   ('miss', 1),
#   ('missile', 1),
#   ('mist', 1),
#   ('mixture', 1),
#   ('moat', 1),
#   ('mode', 1),
#   ('model', 6),
#   ('mom', 3),
#   ('moment', 29),
#   ...]]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=20,
                                           alpha='auto',
                                           per_word_topics=True)
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.021*"jar" + 0.017*"ship" + 0.011*"han" + 0.011*"rey" + 0.008*"vader" + '
#   '0.008*"head" + 0.008*"move" + 0.008*"side" + 0.007*"door" + 0.007*"fire"'),
#  (1,
#   '0.000*"ship" + 0.000*"hand" + 0.000*"moment" + 0.000*"eye" + 0.000*"sir" + '
#   '0.000*"captain" + 0.000*"bruce" + 0.000*"kirk" + 0.000*"time" + '
#   '0.000*"head"'),
#  (2,
#   '0.021*"bruce" + 0.016*"batman" + 0.015*"vicki" + 0.012*"joker" + '
#   '0.009*"hand" + 0.009*"car" + 0.008*"cop" + 0.007*"door" + 0.006*"face" + '
#   '0.006*"street"'),
#  (3,
#   '0.027*"peter" + 0.018*"liz" + 0.010*"door" + 0.009*"flash" + 0.009*"power" '
#   '+ 0.008*"time" + 0.007*"way" + 0.007*"wall" + 0.007*"weiner" + '
#   '0.007*"scimitar"'),
#  (4,
#   '0.028*"kirk" + 0.021*"ship" + 0.015*"captain" + 0.012*"enterprise" + '
#   '0.011*"sir" + 0.010*"datum" + 0.009*"moment" + 0.009*"eye" + 0.008*"mccoy" '
#   '+ 0.008*"bridge"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.076144169418216
#
# Coherence Score:  0.3659236205576027

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, id2word)
vis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7d109a39b34> in <module>
#       1 # Visualize the topics
# ----> 2 pyLDAvis.enable_notebook()
#       3 vis = gensimvis.prepare(lda_model, corpus, id2word)
#       4 vis
#
# NameError: name 'pyLDAvis' is not defined
